# %%
import pandas as pd
import requests
import json
from config import api_key
from pprint import pprint
import matplotlib.pyplot as plt
import csv
import datetime
import numpy as np

# %%
Departure_url = f"http://aviation-edge.com/v2/public/timetable?key={api_key}&iataCode=DFW&type=departure"
#Arrival_url = f"http://aviation-edge.com/v2/public/timetable?key={api_key}&&iataCode=DFW&type=arrival"

# %%
# Performing a GET request similar to the one we executed
# earlier
data = requests.get(Departure_url).json()
#responseA = requests.get(Arrival_url)
pprint(data)
# Out:
# [{'airline': {'iataCode': 'QR', 'icaoCode': 'QTR', 'name': 'Qatar Airways'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': 'T4C2',
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-13T12:50:00.000',
#               'gate': '48B',
#               'iataCode': 'LAX',
#               'icaoCode': 'KLAX',
#               'scheduledTime': '2020-08-13T13:05:00.000',
#               'terminal': '4'},
#   'codeshared': {'airline': {'iataCode': 'aa',
#                              'icaoCode': 'aal',
#                              'name': 'american airlines'},
#                  'flight': {'iataNumber': 'aa2755',
#                             'icaoNumber': 'aal2755',
#                             'number': '2755'}},
#   'departure': {'actualRunway': '2020-08-13T12:13:00.000',
#                 'actualTime': '2020-08-13T12:13:00.000',
#                 'baggage': None,
#                 'delay': '14',
#                 'estimatedRunway': '2020-08-13T12:13:00.000',
#                 'estimatedTime': '2020-08-13T12:15:00.000',
#                 'gate': 'C10',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T12:00:00.000',
#                 'terminal': 'C'},
#   'flight': {'iataNumber': 'QR9024', 'icaoNumber': 'QTR9024', 'number': '9024'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'TN', 'icaoCode': 'THT', 'name': 'Air Tahiti Nui'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': 'T4C2',
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-13T12:50:00.000',
#               'gate': '48B',
#               'iataCode': 'LAX',
#               'icaoCode': 'KLAX',
#               'scheduledTime': '2020-08-13T13:05:00.000',
#               'terminal': '4'},
#   'codeshared': {'airline': {'iataCode': 'aa',
#                              'icaoCode': 'aal',
#                              'name': 'american airlines'},
#                  'flight': {'iataNumber': 'aa2755',
#                             'icaoNumber': 'aal2755',
#                             'number': '2755'}},
#   'departure': {'actualRunway': '2020-08-13T12:13:00.000',
#                 'actualTime': '2020-08-13T12:13:00.000',
#                 'baggage': None,
#                 'delay': '14',
#                 'estimatedRunway': '2020-08-13T12:13:00.000',
#                 'estimatedTime': '2020-08-13T12:15:00.000',
#                 'gate': 'C10',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T12:00:00.000',
#                 'terminal': 'C'},
#   'flight': {'iataNumber': 'TN1193', 'icaoNumber': 'THT1193', 'number': '1193'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'AA', 'icaoCode': 'AAL', 'name': 'American Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': 'T4C2',
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-13T12:50:00.000',
#               'gate': '48B',
#               'iataCode': 'LAX',
#               'icaoCode': 'KLAX',
#               'scheduledTime': '2020-08-13T13:05:00.000',
#               'terminal': '4'},
#   'codeshared': None,
#   'departure': {'actualRunway': '2020-08-13T12:13:00.000',
#                 'actualTime': '2020-08-13T12:13:00.000',
#                 'baggage': None,
#                 'delay': '14',
#                 'estimatedRunway': '2020-08-13T12:13:00.000',
#                 'estimatedTime': '2020-08-13T12:15:00.000',
#                 'gate': 'C10',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T12:00:00.000',
#                 'terminal': 'C'},
#   'flight': {'iataNumber': 'AA2755', 'icaoNumber': 'AAL2755', 'number': '2755'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'NZ', 'icaoCode': 'ANZ', 'name': 'Air New Zealand'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': 'B3',
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-13T12:55:00.000',
#               'gate': 'B87',
#               'iataCode': 'IAH',
#               'icaoCode': 'KIAH',
#               'scheduledTime': '2020-08-13T13:21:00.000',
#               'terminal': 'B'},
#   'codeshared': {'airline': {'iataCode': 'ua',
#                              'icaoCode': 'ual',
#                              'name': 'united airlines'},
#                  'flight': {'iataNumber': 'ua6041',
#                             'icaoNumber': 'ual6041',
#                             'number': '6041'}},
#   'departure': {'actualRunway': '2020-08-13T12:15:00.000',
#                 'actualTime': '2020-08-13T12:15:00.000',
#                 'baggage': None,
#                 'delay': '15',
#                 'estimatedRunway': '2020-08-13T12:15:00.000',
#                 'estimatedTime': '2020-08-13T12:14:00.000',
#                 'gate': 'E7',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T12:00:00.000',
#                 'terminal': 'E'},
#   'flight': {'iataNumber': 'NZ6527', 'icaoNumber': 'ANZ6527', 'number': '6527'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'UA', 'icaoCode': 'UAL', 'name': 'United Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': 'B3',
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-13T12:55:00.000',
#               'gate': 'B87',
#               'iataCode': 'IAH',
#               'icaoCode': 'KIAH',
#               'scheduledTime': '2020-08-13T13:21:00.000',
#               'terminal': 'B'},
#   'codeshared': None,
#   'departure': {'actualRunway': '2020-08-13T12:15:00.000',
#                 'actualTime': '2020-08-13T12:15:00.000',
#                 'baggage': None,
#                 'delay': '15',
#                 'estimatedRunway': '2020-08-13T12:15:00.000',
#                 'estimatedTime': '2020-08-13T12:14:00.000',
#                 'gate': 'E7',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T12:00:00.000',
#                 'terminal': 'E'},
#   'flight': {'iataNumber': 'UA6041', 'icaoNumber': 'UAL6041', 'number': '6041'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'N9', 'icaoCode': 'NVR', 'name': 'Novair'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': None,
#               'gate': None,
#               'iataCode': 'UIN',
#               'icaoCode': 'KUIN',
#               'scheduledTime': '2020-08-13T13:56:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': None,
#                 'actualTime': None,
#                 'baggage': None,
#                 'delay': '21',
#                 'estimatedRunway': None,
#                 'estimatedTime': '2020-08-13T12:21:00.000',
#                 'gate': None,
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T12:00:00.000',
#                 'terminal': None},
#   'flight': {'iataNumber': 'N960RT', 'icaoNumber': 'NVR60RT', 'number': '60RT'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'AA', 'icaoCode': 'AAL', 'name': 'American Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': None,
#               'gate': None,
#               'iataCode': 'SNA',
#               'icaoCode': 'KSNA',
#               'scheduledTime': '2020-08-13T13:05:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': None,
#                 'actualTime': None,
#                 'baggage': None,
#                 'delay': None,
#                 'estimatedRunway': None,
#                 'estimatedTime': None,
#                 'gate': None,
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T12:04:00.000',
#                 'terminal': None},
#   'flight': {'iataNumber': 'AA1104', 'icaoNumber': 'AAL1104', 'number': '1104'},
#   'status': 'cancelled',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'AC', 'icaoCode': 'ACA', 'name': 'Air Canada'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': '16',
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-13T12:52:00.000',
#               'gate': 'B45',
#               'iataCode': 'DEN',
#               'icaoCode': 'KDEN',
#               'scheduledTime': '2020-08-13T13:10:00.000',
#               'terminal': None},
#   'codeshared': {'airline': {'iataCode': 'ua',
#                              'icaoCode': 'ual',
#                              'name': 'united airlines'},
#                  'flight': {'iataNumber': 'ua1407',
#                             'icaoNumber': 'ual1407',
#                             'number': '1407'}},
#   'departure': {'actualRunway': '2020-08-13T12:20:00.000',
#                 'actualTime': '2020-08-13T12:20:00.000',
#                 'baggage': None,
#                 'delay': '16',
#                 'estimatedRunway': '2020-08-13T12:20:00.000',
#                 'estimatedTime': '2020-08-13T12:20:00.000',
#                 'gate': 'E6',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T12:05:00.000',
#                 'terminal': 'E'},
#   'flight': {'iataNumber': 'AC4567', 'icaoNumber': 'ACA4567', 'number': '4567'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'UA', 'icaoCode': 'UAL', 'name': 'United Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': '16',
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-13T12:52:00.000',
#               'gate': 'B45',
#               'iataCode': 'DEN',
#               'icaoCode': 'KDEN',
#               'scheduledTime': '2020-08-13T13:10:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': '2020-08-13T12:20:00.000',
#                 'actualTime': '2020-08-13T12:20:00.000',
#                 'baggage': None,
#                 'delay': '16',
#                 'estimatedRunway': '2020-08-13T12:20:00.000',
#                 'estimatedTime': '2020-08-13T12:20:00.000',
#                 'gate': 'E6',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T12:05:00.000',
#                 'terminal': 'E'},
#   'flight': {'iataNumber': 'UA1407', 'icaoNumber': 'UAL1407', 'number': '1407'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'DL', 'icaoCode': 'DAL', 'name': 'Delta Air Lines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': '8',
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-14T16:02:00.000',
#               'gate': '255',
#               'iataCode': 'ICN',
#               'icaoCode': 'RKSI',
#               'scheduledTime': '2020-08-14T16:40:00.000',
#               'terminal': '2'},
#   'codeshared': {'airline': {'iataCode': 'ke',
#                              'icaoCode': 'kal',
#                              'name': 'korean air'},
#                  'flight': {'iataNumber': 'ke32',
#                             'icaoNumber': 'kal32',
#                             'number': '32'}},
#   'departure': {'actualRunway': '2020-08-13T12:06:00.000',
#                 'actualTime': '2020-08-13T12:06:00.000',
#                 'baggage': None,
#                 'delay': None,
#                 'estimatedRunway': '2020-08-13T12:06:00.000',
#                 'estimatedTime': '2020-08-13T12:20:00.000',
#                 'gate': 'D15',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T12:10:00.000',
#                 'terminal': 'D'},
#   'flight': {'iataNumber': 'DL7868', 'icaoNumber': 'DAL7868', 'number': '7868'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'KE', 'icaoCode': 'KAL', 'name': 'Korean Air'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': '8',
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-14T16:02:00.000',
#               'gate': '255',
#               'iataCode': 'ICN',
#               'icaoCode': 'RKSI',
#               'scheduledTime': '2020-08-14T16:40:00.000',
#               'terminal': '2'},
#   'codeshared': None,
#   'departure': {'actualRunway': '2020-08-13T12:06:00.000',
#                 'actualTime': '2020-08-13T12:06:00.000',
#                 'baggage': None,
#                 'delay': None,
#                 'estimatedRunway': '2020-08-13T12:06:00.000',
#                 'estimatedTime': '2020-08-13T12:20:00.000',
#                 'gate': 'D15',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T12:10:00.000',
#                 'terminal': 'D'},
#   'flight': {'iataNumber': 'KE32', 'icaoNumber': 'KAL32', 'number': '32'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'AA', 'icaoCode': 'AAL', 'name': 'American Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-13T13:30:00.000',
#               'gate': 'A4',
#               'iataCode': 'SMF',
#               'icaoCode': 'KSMF',
#               'scheduledTime': '2020-08-13T13:50:00.000',
#               'terminal': 'A'},
#   'codeshared': None,
#   'departure': {'actualRunway': '2020-08-13T12:27:00.000',
#                 'actualTime': '2020-08-13T12:27:00.000',
#                 'baggage': None,
#                 'delay': '8',
#                 'estimatedRunway': '2020-08-13T12:27:00.000',
#                 'estimatedTime': '2020-08-13T12:31:00.000',
#                 'gate': 'D18',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T12:19:00.000',
#                 'terminal': 'D'},
#   'flight': {'iataNumber': 'AA2308', 'icaoNumber': 'AAL2308', 'number': '2308'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'F9', 'icaoCode': 'FFT', 'name': 'Frontier Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': '4',
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-13T13:20:00.000',
#               'gate': 'A36',
#               'iataCode': 'DEN',
#               'icaoCode': 'KDEN',
#               'scheduledTime': '2020-08-13T13:26:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': '2020-08-13T12:52:00.000',
#                 'actualTime': '2020-08-13T12:52:00.000',
#                 'baggage': None,
#                 'delay': '34',
#                 'estimatedRunway': '2020-08-13T12:52:00.000',
#                 'estimatedTime': '2020-08-13T12:34:00.000',
#                 'gate': 'E20',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T12:19:00.000',
#                 'terminal': 'E'},
#   'flight': {'iataNumber': 'F9265', 'icaoNumber': 'FFT265', 'number': '265'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'AS', 'icaoCode': 'ASA', 'name': 'Alaska Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': '3',
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-13T13:27:00.000',
#               'gate': 'B4',
#               'iataCode': 'SAT',
#               'icaoCode': 'KSAT',
#               'scheduledTime': '2020-08-13T13:24:00.000',
#               'terminal': 'B'},
#   'codeshared': {'airline': {'iataCode': 'aa',
#                              'icaoCode': 'aal',
#                              'name': 'american airlines'},
#                  'flight': {'iataNumber': 'aa35',
#                             'icaoNumber': 'aal35',
#                             'number': '35'}},
#   'departure': {'actualRunway': '2020-08-13T12:44:00.000',
#                 'actualTime': '2020-08-13T12:44:00.000',
#                 'baggage': None,
#                 'delay': '25',
#                 'estimatedRunway': '2020-08-13T12:44:00.000',
#                 'estimatedTime': '2020-08-13T12:40:00.000',
#                 'gate': 'B5',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T12:20:00.000',
#                 'terminal': 'B'},
#   'flight': {'iataNumber': 'AS4684', 'icaoNumber': 'ASA4684', 'number': '4684'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'BA', 'icaoCode': 'BAW', 'name': 'British Airways'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': '3',
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-13T13:27:00.000',
#               'gate': 'B4',
#               'iataCode': 'SAT',
#               'icaoCode': 'KSAT',
#               'scheduledTime': '2020-08-13T13:24:00.000',
#               'terminal': 'B'},
#   'codeshared': {'airline': {'iataCode': 'aa',
#                              'icaoCode': 'aal',
#                              'name': 'american airlines'},
#                  'flight': {'iataNumber': 'aa35',
#                             'icaoNumber': 'aal35',
#                             'number': '35'}},
#   'departure': {'actualRunway': '2020-08-13T12:44:00.000',
#                 'actualTime': '2020-08-13T12:44:00.000',
#                 'baggage': None,
#                 'delay': '25',
#                 'estimatedRunway': '2020-08-13T12:44:00.000',
#                 'estimatedTime': '2020-08-13T12:40:00.000',
#                 'gate': 'B5',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T12:20:00.000',
#                 'terminal': 'B'},
#   'flight': {'iataNumber': 'BA4697', 'icaoNumber': 'BAW4697', 'number': '4697'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'JL', 'icaoCode': 'JTL', 'name': 'Jet Linx Aviation'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': '3',
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-13T13:27:00.000',
#               'gate': 'B4',
#               'iataCode': 'SAT',
#               'icaoCode': 'KSAT',
#               'scheduledTime': '2020-08-13T13:24:00.000',
#               'terminal': 'B'},
#   'codeshared': {'airline': {'iataCode': 'aa',
#                              'icaoCode': 'aal',
#                              'name': 'american airlines'},
#                  'flight': {'iataNumber': 'aa35',
#                             'icaoNumber': 'aal35',
#                             'number': '35'}},
#   'departure': {'actualRunway': '2020-08-13T12:44:00.000',
#                 'actualTime': '2020-08-13T12:44:00.000',
#                 'baggage': None,
#                 'delay': '25',
#                 'estimatedRunway': '2020-08-13T12:44:00.000',
#                 'estimatedTime': '2020-08-13T12:40:00.000',
#                 'gate': 'B5',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T12:20:00.000',
#                 'terminal': 'B'},
#   'flight': {'iataNumber': 'JL7274', 'icaoNumber': 'JTL7274', 'number': '7274'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'AA', 'icaoCode': 'AAL', 'name': 'American Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': '3',
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-13T13:27:00.000',
#               'gate': 'B4',
#               'iataCode': 'SAT',
#               'icaoCode': 'KSAT',
#               'scheduledTime': '2020-08-13T13:24:00.000',
#               'terminal': 'B'},
#   'codeshared': None,
#   'departure': {'actualRunway': '2020-08-13T12:44:00.000',
#                 'actualTime': '2020-08-13T12:44:00.000',
#                 'baggage': None,
#                 'delay': '25',
#                 'estimatedRunway': '2020-08-13T12:44:00.000',
#                 'estimatedTime': '2020-08-13T12:40:00.000',
#                 'gate': 'B5',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T12:20:00.000',
#                 'terminal': 'B'},
#   'flight': {'iataNumber': 'AA35', 'icaoNumber': 'AAL35', 'number': '35'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'AS', 'icaoCode': 'ASA', 'name': 'Alaska Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': '4',
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-13T14:13:00.000',
#               'gate': 'B18',
#               'iataCode': 'BOI',
#               'icaoCode': 'KBOI',
#               'scheduledTime': '2020-08-13T14:35:00.000',
#               'terminal': None},
#   'codeshared': {'airline': {'iataCode': 'aa',
#                              'icaoCode': 'aal',
#                              'name': 'american airlines'},
#                  'flight': {'iataNumber': 'aa1103',
#                             'icaoNumber': 'aal1103',
#                             'number': '1103'}},
#   'departure': {'actualRunway': '2020-08-13T12:28:00.000',
#                 'actualTime': '2020-08-13T12:28:00.000',
#                 'baggage': None,
#                 'delay': '8',
#                 'estimatedRunway': '2020-08-13T12:28:00.000',
#                 'estimatedTime': '2020-08-13T12:32:00.000',
#                 'gate': 'D40',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T12:20:00.000',
#                 'terminal': 'D'},
#   'flight': {'iataNumber': 'AS6105', 'icaoNumber': 'ASA6105', 'number': '6105'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'AA', 'icaoCode': 'AAL', 'name': 'American Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': '4',
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-13T14:13:00.000',
#               'gate': 'B18',
#               'iataCode': 'BOI',
#               'icaoCode': 'KBOI',
#               'scheduledTime': '2020-08-13T14:35:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': '2020-08-13T12:28:00.000',
#                 'actualTime': '2020-08-13T12:28:00.000',
#                 'baggage': None,
#                 'delay': '8',
#                 'estimatedRunway': '2020-08-13T12:28:00.000',
#                 'estimatedTime': '2020-08-13T12:32:00.000',
#                 'gate': 'D40',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T12:20:00.000',
#                 'terminal': 'D'},
#   'flight': {'iataNumber': 'AA1103', 'icaoNumber': 'AAL1103', 'number': '1103'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'AS', 'icaoCode': 'ASA', 'name': 'Alaska Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-13T13:12:00.000',
#               'gate': 'A9',
#               'iataCode': 'TUL',
#               'icaoCode': 'KTUL',
#               'scheduledTime': '2020-08-13T13:25:00.000',
#               'terminal': None},
#   'codeshared': {'airline': {'iataCode': 'aa',
#                              'icaoCode': 'aal',
#                              'name': 'american airlines'},
#                  'flight': {'iataNumber': 'aa2196',
#                             'icaoNumber': 'aal2196',
#                             'number': '2196'}},
#   'departure': {'actualRunway': '2020-08-13T12:27:00.000',
#                 'actualTime': '2020-08-13T12:27:00.000',
#                 'baggage': None,
#                 'delay': '8',
#                 'estimatedRunway': '2020-08-13T12:27:00.000',
#                 'estimatedTime': '2020-08-13T12:30:00.000',
#                 'gate': 'C22',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T12:20:00.000',
#                 'terminal': 'C'},
#   'flight': {'iataNumber': 'AS6164', 'icaoNumber': 'ASA6164', 'number': '6164'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'AA', 'icaoCode': 'AAL', 'name': 'American Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-13T13:12:00.000',
#               'gate': 'A9',
#               'iataCode': 'TUL',
#               'icaoCode': 'KTUL',
#               'scheduledTime': '2020-08-13T13:25:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': '2020-08-13T12:27:00.000',
#                 'actualTime': '2020-08-13T12:27:00.000',
#                 'baggage': None,
#                 'delay': '8',
#                 'estimatedRunway': '2020-08-13T12:27:00.000',
#                 'estimatedTime': '2020-08-13T12:30:00.000',
#                 'gate': 'C22',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T12:20:00.000',
#                 'terminal': 'C'},
#   'flight': {'iataNumber': 'AA2196', 'icaoNumber': 'AAL2196', 'number': '2196'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'AS', 'icaoCode': 'ASA', 'name': 'Alaska Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': '3',
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-13T14:22:00.000',
#               'gate': 'E13',
#               'iataCode': 'MSP',
#               'icaoCode': 'KMSP',
#               'scheduledTime': '2020-08-13T14:44:00.000',
#               'terminal': '1'},
#   'codeshared': {'airline': {'iataCode': 'aa',
#                              'icaoCode': 'aal',
#                              'name': 'american airlines'},
#                  'flight': {'iataNumber': 'aa2203',
#                             'icaoNumber': 'aal2203',
#                             'number': '2203'}},
#   'departure': {'actualRunway': '2020-08-13T12:29:00.000',
#                 'actualTime': '2020-08-13T12:29:00.000',
#                 'baggage': None,
#                 'delay': '9',
#                 'estimatedRunway': '2020-08-13T12:29:00.000',
#                 'estimatedTime': '2020-08-13T12:29:00.000',
#                 'gate': 'A37',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T12:20:00.000',
#                 'terminal': 'A'},
#   'flight': {'iataNumber': 'AS6360', 'icaoNumber': 'ASA6360', 'number': '6360'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'QF', 'icaoCode': 'QFA', 'name': 'Qantas'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': '3',
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-13T14:22:00.000',
#               'gate': 'E13',
#               'iataCode': 'MSP',
#               'icaoCode': 'KMSP',
#               'scheduledTime': '2020-08-13T14:44:00.000',
#               'terminal': '1'},
#   'codeshared': {'airline': {'iataCode': 'aa',
#                              'icaoCode': 'aal',
#                              'name': 'american airlines'},
#                  'flight': {'iataNumber': 'aa2203',
#                             'icaoNumber': 'aal2203',
#                             'number': '2203'}},
#   'departure': {'actualRunway': '2020-08-13T12:29:00.000',
#                 'actualTime': '2020-08-13T12:29:00.000',
#                 'baggage': None,
#                 'delay': '9',
#                 'estimatedRunway': '2020-08-13T12:29:00.000',
#                 'estimatedTime': '2020-08-13T12:29:00.000',
#                 'gate': 'A37',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T12:20:00.000',
#                 'terminal': 'A'},
#   'flight': {'iataNumber': 'QF4795', 'icaoNumber': 'QFA4795', 'number': '4795'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'AA', 'icaoCode': 'AAL', 'name': 'American Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': '3',
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-13T14:22:00.000',
#               'gate': 'E13',
#               'iataCode': 'MSP',
#               'icaoCode': 'KMSP',
#               'scheduledTime': '2020-08-13T14:44:00.000',
#               'terminal': '1'},
#   'codeshared': None,
#   'departure': {'actualRunway': '2020-08-13T12:29:00.000',
#                 'actualTime': '2020-08-13T12:29:00.000',
#                 'baggage': None,
#                 'delay': '9',
#                 'estimatedRunway': '2020-08-13T12:29:00.000',
#                 'estimatedTime': '2020-08-13T12:29:00.000',
#                 'gate': 'A37',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T12:20:00.000',
#                 'terminal': 'A'},
#   'flight': {'iataNumber': 'AA2203', 'icaoNumber': 'AAL2203', 'number': '2203'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'AS', 'icaoCode': 'ASA', 'name': 'Alaska Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': '3',
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-13T13:22:00.000',
#               'gate': '1',
#               'iataCode': 'LIT',
#               'icaoCode': 'KLIT',
#               'scheduledTime': '2020-08-13T13:35:00.000',
#               'terminal': None},
#   'codeshared': {'airline': {'iataCode': 'aa',
#                              'icaoCode': 'aal',
#                              'name': 'american airlines'},
#                  'flight': {'iataNumber': 'aa4173',
#                             'icaoNumber': 'aal4173',
#                             'number': '4173'}},
#   'departure': {'actualRunway': '2020-08-13T12:32:00.000',
#                 'actualTime': '2020-08-13T12:32:00.000',
#                 'baggage': None,
#                 'delay': '13',
#                 'estimatedRunway': '2020-08-13T12:32:00.000',
#                 'estimatedTime': '2020-08-13T12:35:00.000',
#                 'gate': 'B43',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T12:20:00.000',
#                 'terminal': 'B'},
#   'flight': {'iataNumber': 'AS4336', 'icaoNumber': 'ASA4336', 'number': '4336'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'JL', 'icaoCode': 'JTL', 'name': 'Jet Linx Aviation'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': '3',
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-13T13:22:00.000',
#               'gate': '1',
#               'iataCode': 'LIT',
#               'icaoCode': 'KLIT',
#               'scheduledTime': '2020-08-13T13:35:00.000',
#               'terminal': None},
#   'codeshared': {'airline': {'iataCode': 'aa',
#                              'icaoCode': 'aal',
#                              'name': 'american airlines'},
#                  'flight': {'iataNumber': 'aa4173',
#                             'icaoNumber': 'aal4173',
#                             'number': '4173'}},
#   'departure': {'actualRunway': '2020-08-13T12:32:00.000',
#                 'actualTime': '2020-08-13T12:32:00.000',
#                 'baggage': None,
#                 'delay': '13',
#                 'estimatedRunway': '2020-08-13T12:32:00.000',
#                 'estimatedTime': '2020-08-13T12:35:00.000',
#                 'gate': 'B43',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T12:20:00.000',
#                 'terminal': 'B'},
#   'flight': {'iataNumber': 'JL7446', 'icaoNumber': 'JTL7446', 'number': '7446'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'AA', 'icaoCode': 'AAL', 'name': 'American Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': '3',
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-13T13:22:00.000',
#               'gate': '1',
#               'iataCode': 'LIT',
#               'icaoCode': 'KLIT',
#               'scheduledTime': '2020-08-13T13:35:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': '2020-08-13T12:32:00.000',
#                 'actualTime': '2020-08-13T12:32:00.000',
#                 'baggage': None,
#                 'delay': '13',
#                 'estimatedRunway': '2020-08-13T12:32:00.000',
#                 'estimatedTime': '2020-08-13T12:35:00.000',
#                 'gate': 'B43',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T12:20:00.000',
#                 'terminal': 'B'},
#   'flight': {'iataNumber': 'AA4173', 'icaoNumber': 'AAL4173', 'number': '4173'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'BA', 'icaoCode': 'BAW', 'name': 'British Airways'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-13T14:16:00.000',
#               'gate': 'K13',
#               'iataCode': 'ORD',
#               'icaoCode': 'KORD',
#               'scheduledTime': '2020-08-13T14:46:00.000',
#               'terminal': '3'},
#   'codeshared': {'airline': {'iataCode': 'aa',
#                              'icaoCode': 'aal',
#                              'name': 'american airlines'},
#                  'flight': {'iataNumber': 'aa1258',
#                             'icaoNumber': 'aal1258',
#                             'number': '1258'}},
#   'departure': {'actualRunway': '2020-08-13T12:34:00.000',
#                 'actualTime': '2020-08-13T12:34:00.000',
#                 'baggage': None,
#                 'delay': '14',
#                 'estimatedRunway': '2020-08-13T12:34:00.000',
#                 'estimatedTime': '2020-08-13T12:32:00.000',
#                 'gate': 'A34',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T12:20:00.000',
#                 'terminal': 'A'},
#   'flight': {'iataNumber': 'BA5389', 'icaoNumber': 'BAW5389', 'number': '5389'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'AA', 'icaoCode': 'AAL', 'name': 'American Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-13T14:16:00.000',
#               'gate': 'K13',
#               'iataCode': 'ORD',
#               'icaoCode': 'KORD',
#               'scheduledTime': '2020-08-13T14:46:00.000',
#               'terminal': '3'},
#   'codeshared': None,
#   'departure': {'actualRunway': '2020-08-13T12:34:00.000',
#                 'actualTime': '2020-08-13T12:34:00.000',
#                 'baggage': None,
#                 'delay': '14',
#                 'estimatedRunway': '2020-08-13T12:34:00.000',
#                 'estimatedTime': '2020-08-13T12:32:00.000',
#                 'gate': 'A34',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T12:20:00.000',
#                 'terminal': 'A'},
#   'flight': {'iataNumber': 'AA1258', 'icaoNumber': 'AAL1258', 'number': '1258'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'AA', 'icaoCode': 'AAL', 'name': 'American Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': '3',
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-13T13:33:00.000',
#               'gate': '3',
#               'iataCode': 'JAN',
#               'icaoCode': 'KJAN',
#               'scheduledTime': '2020-08-13T13:44:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': '2020-08-13T12:30:00.000',
#                 'actualTime': '2020-08-13T12:30:00.000',
#                 'baggage': None,
#                 'delay': '11',
#                 'estimatedRunway': '2020-08-13T12:30:00.000',
#                 'estimatedTime': '2020-08-13T12:31:00.000',
#                 'gate': 'B18',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T12:20:00.000',
#                 'terminal': 'B'},
#   'flight': {'iataNumber': 'AA3610', 'icaoNumber': 'AAL3610', 'number': '3610'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'AA', 'icaoCode': 'AAL', 'name': 'American Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': '1',
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-13T13:19:00.000',
#               'gate': '1',
#               'iataCode': 'SWO',
#               'icaoCode': 'KSWO',
#               'scheduledTime': '2020-08-13T13:27:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': '2020-08-13T12:37:00.000',
#                 'actualTime': '2020-08-13T12:37:00.000',
#                 'baggage': None,
#                 'delay': '17',
#                 'estimatedRunway': '2020-08-13T12:37:00.000',
#                 'estimatedTime': '2020-08-13T12:35:00.000',
#                 'gate': 'E24',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T12:20:00.000',
#                 'terminal': 'E'},
#   'flight': {'iataNumber': 'AA3607', 'icaoNumber': 'AAL3607', 'number': '3607'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'DL', 'icaoCode': 'DAL', 'name': 'Delta Air Lines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': None,
#               'gate': None,
#               'iataCode': 'MEX',
#               'icaoCode': 'MMMX',
#               'scheduledTime': '2020-08-13T15:10:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': None,
#                 'actualTime': None,
#                 'baggage': None,
#                 'delay': None,
#                 'estimatedRunway': None,
#                 'estimatedTime': None,
#                 'gate': None,
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T12:20:00.000',
#                 'terminal': None},
#   'flight': {'iataNumber': 'DL8124', 'icaoNumber': 'DAL8124', 'number': '8124'},
#   'status': 'cancelled',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'AA', 'icaoCode': 'AAL', 'name': 'American Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': None,
#               'gate': None,
#               'iataCode': 'CRP',
#               'icaoCode': 'KCRP',
#               'scheduledTime': '2020-08-13T13:34:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': None,
#                 'actualTime': None,
#                 'baggage': None,
#                 'delay': None,
#                 'estimatedRunway': None,
#                 'estimatedTime': None,
#                 'gate': None,
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T12:20:00.000',
#                 'terminal': None},
#   'flight': {'iataNumber': 'AA3375', 'icaoNumber': 'AAL3375', 'number': '3375'},
#   'status': 'cancelled',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'AS', 'icaoCode': 'ASA', 'name': 'Alaska Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-13T13:37:00.000',
#               'gate': 'B16',
#               'iataCode': 'MSY',
#               'icaoCode': 'KMSY',
#               'scheduledTime': '2020-08-13T13:51:00.000',
#               'terminal': None},
#   'codeshared': {'airline': {'iataCode': 'aa',
#                              'icaoCode': 'aal',
#                              'name': 'american airlines'},
#                  'flight': {'iataNumber': 'aa130',
#                             'icaoNumber': 'aal130',
#                             'number': '130'}},
#   'departure': {'actualRunway': '2020-08-13T12:28:00.000',
#                 'actualTime': '2020-08-13T12:28:00.000',
#                 'baggage': None,
#                 'delay': '7',
#                 'estimatedRunway': '2020-08-13T12:28:00.000',
#                 'estimatedTime': '2020-08-13T12:32:00.000',
#                 'gate': 'C27',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T12:22:00.000',
#                 'terminal': 'C'},
#   'flight': {'iataNumber': 'AS6135', 'icaoNumber': 'ASA6135', 'number': '6135'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'BA', 'icaoCode': 'BAW', 'name': 'British Airways'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-13T13:37:00.000',
#               'gate': 'B16',
#               'iataCode': 'MSY',
#               'icaoCode': 'KMSY',
#               'scheduledTime': '2020-08-13T13:51:00.000',
#               'terminal': None},
#   'codeshared': {'airline': {'iataCode': 'aa',
#                              'icaoCode': 'aal',
#                              'name': 'american airlines'},
#                  'flight': {'iataNumber': 'aa130',
#                             'icaoNumber': 'aal130',
#                             'number': '130'}},
#   'departure': {'actualRunway': '2020-08-13T12:28:00.000',
#                 'actualTime': '2020-08-13T12:28:00.000',
#                 'baggage': None,
#                 'delay': '7',
#                 'estimatedRunway': '2020-08-13T12:28:00.000',
#                 'estimatedTime': '2020-08-13T12:32:00.000',
#                 'gate': 'C27',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T12:22:00.000',
#                 'terminal': 'C'},
#   'flight': {'iataNumber': 'BA6727', 'icaoNumber': 'BAW6727', 'number': '6727'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'JL', 'icaoCode': 'JTL', 'name': 'Jet Linx Aviation'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-13T13:37:00.000',
#               'gate': 'B16',
#               'iataCode': 'MSY',
#               'icaoCode': 'KMSY',
#               'scheduledTime': '2020-08-13T13:51:00.000',
#               'terminal': None},
#   'codeshared': {'airline': {'iataCode': 'aa',
#                              'icaoCode': 'aal',
#                              'name': 'american airlines'},
#                  'flight': {'iataNumber': 'aa130',
#                             'icaoNumber': 'aal130',
#                             'number': '130'}},
#   'departure': {'actualRunway': '2020-08-13T12:28:00.000',
#                 'actualTime': '2020-08-13T12:28:00.000',
#                 'baggage': None,
#                 'delay': '7',
#                 'estimatedRunway': '2020-08-13T12:28:00.000',
#                 'estimatedTime': '2020-08-13T12:32:00.000',
#                 'gate': 'C27',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T12:22:00.000',
#                 'terminal': 'C'},
#   'flight': {'iataNumber': 'JL7266', 'icaoNumber': 'JTL7266', 'number': '7266'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'QF', 'icaoCode': 'QFA', 'name': 'Qantas'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-13T13:37:00.000',
#               'gate': 'B16',
#               'iataCode': 'MSY',
#               'icaoCode': 'KMSY',
#               'scheduledTime': '2020-08-13T13:51:00.000',
#               'terminal': None},
#   'codeshared': {'airline': {'iataCode': 'aa',
#                              'icaoCode': 'aal',
#                              'name': 'american airlines'},
#                  'flight': {'iataNumber': 'aa130',
#                             'icaoNumber': 'aal130',
#                             'number': '130'}},
#   'departure': {'actualRunway': '2020-08-13T12:28:00.000',
#                 'actualTime': '2020-08-13T12:28:00.000',
#                 'baggage': None,
#                 'delay': '7',
#                 'estimatedRunway': '2020-08-13T12:28:00.000',
#                 'estimatedTime': '2020-08-13T12:32:00.000',
#                 'gate': 'C27',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T12:22:00.000',
#                 'terminal': 'C'},
#   'flight': {'iataNumber': 'QF4820', 'icaoNumber': 'QFA4820', 'number': '4820'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'AA', 'icaoCode': 'AAL', 'name': 'American Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-13T13:37:00.000',
#               'gate': 'B16',
#               'iataCode': 'MSY',
#               'icaoCode': 'KMSY',
#               'scheduledTime': '2020-08-13T13:51:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': '2020-08-13T12:28:00.000',
#                 'actualTime': '2020-08-13T12:28:00.000',
#                 'baggage': None,
#                 'delay': '7',
#                 'estimatedRunway': '2020-08-13T12:28:00.000',
#                 'estimatedTime': '2020-08-13T12:32:00.000',
#                 'gate': 'C27',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
# ...
#                 'estimatedTime': None,
#                 'gate': None,
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T21:14:00.000',
#                 'terminal': None},
#   'flight': {'iataNumber': '5X765', 'icaoNumber': 'UPS765', 'number': '765'},
#   'status': 'scheduled',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'FX', 'icaoCode': 'FDX', 'name': 'FedEx'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': None,
#               'gate': None,
#               'iataCode': 'MEM',
#               'icaoCode': 'KMEM',
#               'scheduledTime': '2020-08-13T22:56:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': None,
#                 'actualTime': None,
#                 'baggage': None,
#                 'delay': '15',
#                 'estimatedRunway': None,
#                 'estimatedTime': '2020-08-13T21:53:00.000',
#                 'gate': None,
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T21:38:00.000',
#                 'terminal': None},
#   'flight': {'iataNumber': 'FX1201', 'icaoNumber': 'FDX1201', 'number': '1201'},
#   'status': 'scheduled',
#   'type': 'departure'},
#  {'airline': {'iataCode': '5X', 'icaoCode': 'UPS', 'name': 'UPS Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': None,
#               'gate': None,
#               'iataCode': 'SDF',
#               'icaoCode': 'KSDF',
#               'scheduledTime': '2020-08-14T00:35:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': None,
#                 'actualTime': None,
#                 'baggage': None,
#                 'delay': None,
#                 'estimatedRunway': None,
#                 'estimatedTime': None,
#                 'gate': None,
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T21:44:00.000',
#                 'terminal': None},
#   'flight': {'iataNumber': '5X767', 'icaoNumber': 'UPS767', 'number': '767'},
#   'status': 'scheduled',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'QR', 'icaoCode': 'QTR', 'name': 'Qatar Airways'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': None,
#               'gate': None,
#               'iataCode': 'LUX',
#               'icaoCode': 'ELLX',
#               'scheduledTime': '2020-08-14T14:30:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': None,
#                 'actualTime': None,
#                 'baggage': None,
#                 'delay': '10',
#                 'estimatedRunway': None,
#                 'estimatedTime': '2020-08-13T22:05:00.000',
#                 'gate': None,
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T21:55:00.000',
#                 'terminal': None},
#   'flight': {'iataNumber': 'QR8132', 'icaoNumber': 'QTR8132', 'number': '8132'},
#   'status': 'scheduled',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'FX', 'icaoCode': 'FDX', 'name': 'FedEx'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': None,
#               'gate': None,
#               'iataCode': 'IND',
#               'icaoCode': 'KIND',
#               'scheduledTime': '2020-08-14T00:48:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': None,
#                 'actualTime': None,
#                 'baggage': None,
#                 'delay': '14',
#                 'estimatedRunway': None,
#                 'estimatedTime': '2020-08-13T22:09:00.000',
#                 'gate': None,
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T21:55:00.000',
#                 'terminal': None},
#   'flight': {'iataNumber': 'FX1609', 'icaoNumber': 'FDX1609', 'number': '1609'},
#   'status': 'scheduled',
#   'type': 'departure'},
#  {'airline': {'iataCode': '5X', 'icaoCode': 'UPS', 'name': 'UPS Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': None,
#               'gate': None,
#               'iataCode': 'RFD',
#               'icaoCode': 'KRFD',
#               'scheduledTime': '2020-08-13T23:59:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': None,
#                 'actualTime': None,
#                 'baggage': None,
#                 'delay': None,
#                 'estimatedRunway': None,
#                 'estimatedTime': None,
#                 'gate': None,
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T22:10:00.000',
#                 'terminal': None},
#   'flight': {'iataNumber': '5X753', 'icaoNumber': 'UPS753', 'number': '753'},
#   'status': 'scheduled',
#   'type': 'departure'},
#  {'airline': {'iataCode': '5X', 'icaoCode': 'UPS', 'name': 'UPS Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': None,
#               'gate': None,
#               'iataCode': 'SDF',
#               'icaoCode': 'KSDF',
#               'scheduledTime': '2020-08-14T01:09:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': None,
#                 'actualTime': None,
#                 'baggage': None,
#                 'delay': None,
#                 'estimatedRunway': None,
#                 'estimatedTime': None,
#                 'gate': None,
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T22:16:00.000',
#                 'terminal': None},
#   'flight': {'iataNumber': '5X793', 'icaoNumber': 'UPS793', 'number': '793'},
#   'status': 'scheduled',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'K4', 'icaoCode': 'CKS', 'name': 'Kalitta Air'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': None,
#               'gate': None,
#               'iataCode': 'CVG',
#               'icaoCode': 'KCVG',
#               'scheduledTime': '2020-08-14T01:30:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': None,
#                 'actualTime': None,
#                 'baggage': None,
#                 'delay': None,
#                 'estimatedRunway': None,
#                 'estimatedTime': None,
#                 'gate': None,
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T22:30:00.000',
#                 'terminal': None},
#   'flight': {'iataNumber': 'K4102', 'icaoNumber': 'CKS102', 'number': '102'},
#   'status': 'scheduled',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'FX', 'icaoCode': 'FDX', 'name': 'FedEx'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': None,
#               'gate': None,
#               'iataCode': 'IND',
#               'icaoCode': 'KIND',
#               'scheduledTime': '2020-08-14T01:32:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': None,
#                 'actualTime': None,
#                 'baggage': None,
#                 'delay': '14',
#                 'estimatedRunway': None,
#                 'estimatedTime': '2020-08-13T22:53:00.000',
#                 'gate': None,
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T22:39:00.000',
#                 'terminal': None},
#   'flight': {'iataNumber': 'FX1601', 'icaoNumber': 'FDX1601', 'number': '1601'},
#   'status': 'scheduled',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'FX', 'icaoCode': 'FDX', 'name': 'FedEx'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': None,
#               'gate': None,
#               'iataCode': 'MEM',
#               'icaoCode': 'KMEM',
#               'scheduledTime': '2020-08-14T00:16:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': None,
#                 'actualTime': None,
#                 'baggage': None,
#                 'delay': '16',
#                 'estimatedRunway': None,
#                 'estimatedTime': '2020-08-13T23:11:00.000',
#                 'gate': None,
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T22:55:00.000',
#                 'terminal': None},
#   'flight': {'iataNumber': 'FX1365', 'icaoNumber': 'FDX1365', 'number': '1365'},
#   'status': 'scheduled',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'NK', 'icaoCode': 'NKS', 'name': 'Spirit Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': None,
#               'gate': 'F3',
#               'iataCode': 'PHX',
#               'icaoCode': 'KPHX',
#               'scheduledTime': '2020-08-13T23:39:00.000',
#               'terminal': '3'},
#   'codeshared': None,
#   'departure': {'actualRunway': None,
#                 'actualTime': None,
#                 'baggage': None,
#                 'delay': '8',
#                 'estimatedRunway': None,
#                 'estimatedTime': '2020-08-13T23:23:00.000',
#                 'gate': 'E31',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T23:15:00.000',
#                 'terminal': 'E'},
#   'flight': {'iataNumber': 'NK1971', 'icaoNumber': 'NKS1971', 'number': '1971'},
#   'status': 'scheduled',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'CV', 'icaoCode': 'CLX', 'name': 'Cargolux'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': None,
#               'gate': None,
#               'iataCode': 'MIA',
#               'icaoCode': 'KMIA',
#               'scheduledTime': '2020-08-14T05:05:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': None,
#                 'actualTime': None,
#                 'baggage': None,
#                 'delay': None,
#                 'estimatedRunway': None,
#                 'estimatedTime': None,
#                 'gate': None,
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-14T00:05:00.000',
#                 'terminal': None},
#   'flight': {'iataNumber': 'CV6584', 'icaoNumber': 'CLX6584', 'number': '6584'},
#   'status': 'scheduled',
#   'type': 'departure'},
#  {'airline': {'iataCode': '5X', 'icaoCode': 'UPS', 'name': 'UPS Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': None,
#               'gate': None,
#               'iataCode': 'SDF',
#               'icaoCode': 'KSDF',
#               'scheduledTime': '2020-08-14T03:08:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': None,
#                 'actualTime': None,
#                 'baggage': None,
#                 'delay': None,
#                 'estimatedRunway': None,
#                 'estimatedTime': None,
#                 'gate': None,
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-14T00:16:00.000',
#                 'terminal': None},
#   'flight': {'iataNumber': '5X9744', 'icaoNumber': 'UPS9744', 'number': '9744'},
#   'status': 'scheduled',
#   'type': 'departure'},
#  {'airline': {'iataCode': '5X', 'icaoCode': 'UPS', 'name': 'UPS Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': None,
#               'gate': None,
#               'iataCode': 'SDF',
#               'icaoCode': 'KSDF',
#               'scheduledTime': '2020-08-14T03:12:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': None,
#                 'actualTime': None,
#                 'baggage': None,
#                 'delay': None,
#                 'estimatedRunway': None,
#                 'estimatedTime': None,
#                 'gate': None,
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-14T00:20:00.000',
#                 'terminal': None},
#   'flight': {'iataNumber': '5X9721', 'icaoNumber': 'UPS9721', 'number': '9721'},
#   'status': 'scheduled',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'CV', 'icaoCode': 'CLX', 'name': 'Cargolux'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': None,
#               'gate': None,
#               'iataCode': 'MIA',
#               'icaoCode': 'KMIA',
#               'scheduledTime': '2020-08-14T02:50:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': None,
#                 'actualTime': None,
#                 'baggage': None,
#                 'delay': None,
#                 'estimatedRunway': None,
#                 'estimatedTime': None,
#                 'gate': None,
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-14T01:05:00.000',
#                 'terminal': None},
#   'flight': {'iataNumber': 'CV6595', 'icaoNumber': 'CLX6595', 'number': '6595'},
#   'status': 'scheduled',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'SQ',
#               'icaoCode': 'SIA',
#               'name': 'Singapore Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': None,
#               'gate': None,
#               'iataCode': 'BRU',
#               'icaoCode': 'EBBR',
#               'scheduledTime': '2020-08-14T17:40:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': None,
#                 'actualTime': None,
#                 'baggage': None,
#                 'delay': None,
#                 'estimatedRunway': None,
#                 'estimatedTime': None,
#                 'gate': None,
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-14T01:25:00.000',
#                 'terminal': None},
#   'flight': {'iataNumber': 'SQ7951', 'icaoNumber': 'SIA7951', 'number': '7951'},
#   'status': 'scheduled',
#   'type': 'departure'}]

# %%
#JB-added terminal to the list which will give us another lookup option
names= []
times= []
flights=[]
terminal= []
length = int(len(data)-1)

for x in range(0,length):
    names.append(data[x]["airline"]["name"])
    Time = data[x]["departure"]["scheduledTime"]
    TimeSplit = Time.split("T")[1]
    times.append(TimeSplit[:5])
    flights.append(data[x]["flight"]["iataNumber"])
    terminal.append(data[x]["departure"]["terminal"])
df = pd.DataFrame()
df["name"] =names
df["scheduledTime"] =pd.to_datetime(times)
df["iataNumber"]=flights
df["Terminal"]=terminal

df
# Out:
#                    name       scheduledTime iataNumber Terminal
# 0         Qatar Airways 2020-08-13 12:00:00     QR9024        C
# 1        Air Tahiti Nui 2020-08-13 12:00:00     TN1193        C
# 2     American Airlines 2020-08-13 12:00:00     AA2755        C
# 3       Air New Zealand 2020-08-13 12:00:00     NZ6527        E
# 4       United Airlines 2020-08-13 12:00:00     UA6041        E
# ...                 ...                 ...        ...      ...
# 1030    Spirit Airlines 2020-08-13 23:15:00     NK1971        E
# 1031           Cargolux 2020-08-13 00:05:00     CV6584     None
# 1032       UPS Airlines 2020-08-13 00:16:00     5X9744     None
# 1033       UPS Airlines 2020-08-13 00:20:00     5X9721     None
# 1034           Cargolux 2020-08-13 01:05:00     CV6595     None
#
# [1035 rows x 4 columns]

# %%
# Playing around with time format
time_df = df["scheduledTime"]
time_fixed = time_df.map(lambda x: x.strftime("%b %d %Y %I:%M %p"))
time_fixed
# Out:
# 0       Aug 13 2020 12:00 PM
# 1       Aug 13 2020 12:00 PM
# 2       Aug 13 2020 12:00 PM
# 3       Aug 13 2020 12:00 PM
# 4       Aug 13 2020 12:00 PM
#                 ...
# 1030    Aug 13 2020 11:15 PM
# 1031    Aug 13 2020 12:05 AM
# 1032    Aug 13 2020 12:16 AM
# 1033    Aug 13 2020 12:20 AM
# 1034    Aug 13 2020 01:05 AM
# Name: scheduledTime, Length: 1035, dtype: object

# %%
#df.to_csv("airport_data.csv", encoding="utf-8", index=False, header=True)
test = df.groupby(["scheduledTime"])["iataNumber"].count()
test.plot(kind="line", color="green", title="Flight per Hour", fontsize=20, figsize = (40,10))
plt.xlabel("Schedule Time", fontsize=30)
plt.ylabel("Number of Flights", fontsize=30)
plt.title("Flight per Hour", fontsize=40)
plt.xlim("2020-08-13 12:00:00","2020-08-13 23:20:00")

# x_axis = np.arange(test_df)
# tick_locations = [value for value in x_axis]
# xticks=["midnight","3am","6am","9am","noon","3pm","6pm","9pm","midnight"]
# plt.xticks(tick_locations, test_df["scheduledTime"])
# Out:
# (737650.5, 737650.9722222222)
