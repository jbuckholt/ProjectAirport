# %%
import pandas as pd
import requests
import json
from config import api_key
from pprint import pprint
import matplotlib.pyplot as plt
import csv
import datetime
import numpy as np

# %%
Departure_url = f"http://aviation-edge.com/v2/public/timetable?key={api_key}&iataCode=DFW&type=departure"
#Arrival_url = f"http://aviation-edge.com/v2/public/timetable?key={api_key}&&iataCode=DFW&type=arrival"

# %%
# Performing a GET request similar to the one we executed
# earlier
data = requests.get(Departure_url).json()
#responseA = requests.get(Arrival_url)
pprint(data)
# Out:
# [{'airline': {'iataCode': 'AA', 'icaoCode': 'AAL', 'name': 'American Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': '4',
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-13T09:45:00.000',
#               'gate': 'B3',
#               'iataCode': 'ABQ',
#               'icaoCode': 'KABQ',
#               'scheduledTime': '2020-08-13T09:50:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': '2020-08-13T09:26:00.000',
#                 'actualTime': '2020-08-13T09:26:00.000',
#                 'baggage': None,
#                 'delay': '26',
#                 'estimatedRunway': '2020-08-13T09:26:00.000',
#                 'estimatedTime': '2020-08-13T09:18:00.000',
#                 'gate': 'C28',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T09:00:00.000',
#                 'terminal': 'C'},
#   'flight': {'iataNumber': 'AA2420', 'icaoNumber': 'AAL2420', 'number': '2420'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'AA', 'icaoCode': 'AAL', 'name': 'American Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': '4',
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-13T09:42:00.000',
#               'gate': '8',
#               'iataCode': 'COS',
#               'icaoCode': 'KCOS',
#               'scheduledTime': '2020-08-13T09:59:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': '2020-08-13T09:14:00.000',
#                 'actualTime': '2020-08-13T09:14:00.000',
#                 'baggage': None,
#                 'delay': '15',
#                 'estimatedRunway': '2020-08-13T09:14:00.000',
#                 'estimatedTime': '2020-08-13T09:15:00.000',
#                 'gate': 'A28',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T09:00:00.000',
#                 'terminal': 'C'},
#   'flight': {'iataNumber': 'AA2810', 'icaoNumber': 'AAL2810', 'number': '2810'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'AA', 'icaoCode': 'AAL', 'name': 'American Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': '1',
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-13T11:06:00.000',
#               'gate': '7',
#               'iataCode': 'MSO',
#               'icaoCode': 'KMSO',
#               'scheduledTime': '2020-08-13T11:26:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': '2020-08-13T09:11:00.000',
#                 'actualTime': '2020-08-13T09:11:00.000',
#                 'baggage': None,
#                 'delay': '11',
#                 'estimatedRunway': '2020-08-13T09:11:00.000',
#                 'estimatedTime': '2020-08-13T09:21:00.000',
#                 'gate': 'B42',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T09:00:00.000',
#                 'terminal': 'B'},
#   'flight': {'iataNumber': 'AA3333', 'icaoNumber': 'AAL3333', 'number': '3333'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'AS', 'icaoCode': 'ASA', 'name': 'Alaska Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-13T09:25:00.000',
#               'gate': 'A2',
#               'iataCode': 'ELP',
#               'icaoCode': 'KELP',
#               'scheduledTime': '2020-08-13T09:43:00.000',
#               'terminal': None},
#   'codeshared': {'airline': {'iataCode': 'aa',
#                              'icaoCode': 'aal',
#                              'name': 'american airlines'},
#                  'flight': {'iataNumber': 'aa5751',
#                             'icaoNumber': 'aal5751',
#                             'number': '5751'}},
#   'departure': {'actualRunway': '2020-08-13T09:11:00.000',
#                 'actualTime': '2020-08-13T09:11:00.000',
#                 'baggage': None,
#                 'delay': '12',
#                 'estimatedRunway': '2020-08-13T09:11:00.000',
#                 'estimatedTime': '2020-08-13T09:19:00.000',
#                 'gate': 'B35',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T09:00:00.000',
#                 'terminal': 'B'},
#   'flight': {'iataNumber': 'AS4005', 'icaoNumber': 'ASA4005', 'number': '4005'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'AA', 'icaoCode': 'AAL', 'name': 'American Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-13T09:25:00.000',
#               'gate': 'A2',
#               'iataCode': 'ELP',
#               'icaoCode': 'KELP',
#               'scheduledTime': '2020-08-13T09:43:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': '2020-08-13T09:11:00.000',
#                 'actualTime': '2020-08-13T09:11:00.000',
#                 'baggage': None,
#                 'delay': '12',
#                 'estimatedRunway': '2020-08-13T09:11:00.000',
#                 'estimatedTime': '2020-08-13T09:19:00.000',
#                 'gate': 'B35',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T09:00:00.000',
#                 'terminal': 'B'},
#   'flight': {'iataNumber': 'AA5751', 'icaoNumber': 'AAL5751', 'number': '5751'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'QF', 'icaoCode': 'QFA', 'name': 'Qantas'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': 'F',
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-13T12:57:00.000',
#               'gate': 'C22',
#               'iataCode': 'PHL',
#               'icaoCode': 'KPHL',
#               'scheduledTime': '2020-08-13T13:22:00.000',
#               'terminal': 'C'},
#   'codeshared': {'airline': {'iataCode': 'aa',
#                              'icaoCode': 'aal',
#                              'name': 'american airlines'},
#                  'flight': {'iataNumber': 'aa402',
#                             'icaoNumber': 'aal402',
#                             'number': '402'}},
#   'departure': {'actualRunway': '2020-08-13T09:10:00.000',
#                 'actualTime': '2020-08-13T09:10:00.000',
#                 'baggage': None,
#                 'delay': '11',
#                 'estimatedRunway': '2020-08-13T09:10:00.000',
#                 'estimatedTime': '2020-08-13T09:13:00.000',
#                 'gate': 'C14',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T09:00:00.000',
#                 'terminal': 'C'},
#   'flight': {'iataNumber': 'QF3125', 'icaoNumber': 'QFA3125', 'number': '3125'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'AA', 'icaoCode': 'AAL', 'name': 'American Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': 'F',
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-13T12:57:00.000',
#               'gate': 'C22',
#               'iataCode': 'PHL',
#               'icaoCode': 'KPHL',
#               'scheduledTime': '2020-08-13T13:22:00.000',
#               'terminal': 'C'},
#   'codeshared': None,
#   'departure': {'actualRunway': '2020-08-13T09:10:00.000',
#                 'actualTime': '2020-08-13T09:10:00.000',
#                 'baggage': None,
#                 'delay': '11',
#                 'estimatedRunway': '2020-08-13T09:10:00.000',
#                 'estimatedTime': '2020-08-13T09:13:00.000',
#                 'gate': 'C14',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T09:00:00.000',
#                 'terminal': 'C'},
#   'flight': {'iataNumber': 'AA402', 'icaoNumber': 'AAL402', 'number': '402'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'QF', 'icaoCode': 'QFA', 'name': 'Qantas'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': 'T4C1',
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-13T10:21:00.000',
#               'gate': '42B',
#               'iataCode': 'LAX',
#               'icaoCode': 'KLAX',
#               'scheduledTime': '2020-08-13T10:25:00.000',
#               'terminal': '4'},
#   'codeshared': {'airline': {'iataCode': 'aa',
#                              'icaoCode': 'aal',
#                              'name': 'american airlines'},
#                  'flight': {'iataNumber': 'aa971',
#                             'icaoNumber': 'aal971',
#                             'number': '971'}},
#   'departure': {'actualRunway': '2020-08-13T09:44:00.000',
#                 'actualTime': '2020-08-13T09:44:00.000',
#                 'baggage': None,
#                 'delay': '45',
#                 'estimatedRunway': '2020-08-13T09:44:00.000',
#                 'estimatedTime': '2020-08-13T09:43:00.000',
#                 'gate': 'D22',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T09:00:00.000',
#                 'terminal': 'D'},
#   'flight': {'iataNumber': 'QF4320', 'icaoNumber': 'QFA4320', 'number': '4320'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'TN', 'icaoCode': 'THT', 'name': 'Air Tahiti Nui'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': 'T4C1',
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-13T10:21:00.000',
#               'gate': '42B',
#               'iataCode': 'LAX',
#               'icaoCode': 'KLAX',
#               'scheduledTime': '2020-08-13T10:25:00.000',
#               'terminal': '4'},
#   'codeshared': {'airline': {'iataCode': 'aa',
#                              'icaoCode': 'aal',
#                              'name': 'american airlines'},
#                  'flight': {'iataNumber': 'aa971',
#                             'icaoNumber': 'aal971',
#                             'number': '971'}},
#   'departure': {'actualRunway': '2020-08-13T09:44:00.000',
#                 'actualTime': '2020-08-13T09:44:00.000',
#                 'baggage': None,
#                 'delay': '45',
#                 'estimatedRunway': '2020-08-13T09:44:00.000',
#                 'estimatedTime': '2020-08-13T09:43:00.000',
#                 'gate': 'D22',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T09:00:00.000',
#                 'terminal': 'D'},
#   'flight': {'iataNumber': 'TN1191', 'icaoNumber': 'THT1191', 'number': '1191'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'AA', 'icaoCode': 'AAL', 'name': 'American Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': 'T4C1',
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-13T10:21:00.000',
#               'gate': '42B',
#               'iataCode': 'LAX',
#               'icaoCode': 'KLAX',
#               'scheduledTime': '2020-08-13T10:25:00.000',
#               'terminal': '4'},
#   'codeshared': None,
#   'departure': {'actualRunway': '2020-08-13T09:44:00.000',
#                 'actualTime': '2020-08-13T09:44:00.000',
#                 'baggage': None,
#                 'delay': '45',
#                 'estimatedRunway': '2020-08-13T09:44:00.000',
#                 'estimatedTime': '2020-08-13T09:43:00.000',
#                 'gate': 'D22',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T09:00:00.000',
#                 'terminal': 'D'},
#   'flight': {'iataNumber': 'AA971', 'icaoNumber': 'AAL971', 'number': '971'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': '', 'icaoCode': 'DPJ', 'name': 'Delta Private Jets'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': None,
#               'gate': None,
#               'iataCode': 'FTW',
#               'icaoCode': 'KFTW',
#               'scheduledTime': '2020-08-13T09:15:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': None,
#                 'actualTime': None,
#                 'baggage': None,
#                 'delay': '35',
#                 'estimatedRunway': None,
#                 'estimatedTime': '2020-08-13T09:35:00.000',
#                 'gate': None,
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T09:00:00.000',
#                 'terminal': None},
#   'flight': {'iataNumber': '', 'icaoNumber': 'DPJ707', 'number': '707'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'AA', 'icaoCode': 'AAL', 'name': 'American Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': 'LM9',
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-13T10:53:00.000',
#               'gate': 'C17',
#               'iataCode': 'PDX',
#               'icaoCode': 'KPDX',
#               'scheduledTime': '2020-08-13T11:03:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': '2020-08-13T09:27:00.000',
#                 'actualTime': '2020-08-13T09:27:00.000',
#                 'baggage': None,
#                 'delay': '27',
#                 'estimatedRunway': '2020-08-13T09:27:00.000',
#                 'estimatedTime': '2020-08-13T09:21:00.000',
#                 'gate': 'A37',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T09:01:00.000',
#                 'terminal': 'A'},
#   'flight': {'iataNumber': 'AA1316', 'icaoNumber': 'AAL1316', 'number': '1316'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'QF', 'icaoCode': 'QFA', 'name': 'Qantas'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': '4',
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-13T10:40:00.000',
#               'gate': 'B25',
#               'iataCode': 'SFO',
#               'icaoCode': 'KSFO',
#               'scheduledTime': '2020-08-13T10:54:00.000',
#               'terminal': '1'},
#   'codeshared': {'airline': {'iataCode': 'aa',
#                              'icaoCode': 'aal',
#                              'name': 'american airlines'},
#                  'flight': {'iataNumber': 'aa1260',
#                             'icaoNumber': 'aal1260',
#                             'number': '1260'}},
#   'departure': {'actualRunway': '2020-08-13T09:34:00.000',
#                 'actualTime': '2020-08-13T09:34:00.000',
#                 'baggage': None,
#                 'delay': '29',
#                 'estimatedRunway': '2020-08-13T09:34:00.000',
#                 'estimatedTime': '2020-08-13T09:28:00.000',
#                 'gate': 'C20',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T09:05:00.000',
#                 'terminal': 'C'},
#   'flight': {'iataNumber': 'QF4572', 'icaoNumber': 'QFA4572', 'number': '4572'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'AA', 'icaoCode': 'AAL', 'name': 'American Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': '4',
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-13T10:40:00.000',
#               'gate': 'B25',
#               'iataCode': 'SFO',
#               'icaoCode': 'KSFO',
#               'scheduledTime': '2020-08-13T10:54:00.000',
#               'terminal': '1'},
#   'codeshared': None,
#   'departure': {'actualRunway': '2020-08-13T09:34:00.000',
#                 'actualTime': '2020-08-13T09:34:00.000',
#                 'baggage': None,
#                 'delay': '29',
#                 'estimatedRunway': '2020-08-13T09:34:00.000',
#                 'estimatedTime': '2020-08-13T09:28:00.000',
#                 'gate': 'C20',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T09:05:00.000',
#                 'terminal': 'C'},
#   'flight': {'iataNumber': 'AA1260', 'icaoNumber': 'AAL1260', 'number': '1260'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'AS', 'icaoCode': 'ASA', 'name': 'Alaska Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-13T10:51:00.000',
#               'gate': 'C10',
#               'iataCode': 'BNA',
#               'icaoCode': 'KBNA',
#               'scheduledTime': '2020-08-13T11:03:00.000',
#               'terminal': None},
#   'codeshared': {'airline': {'iataCode': 'aa',
#                              'icaoCode': 'aal',
#                              'name': 'american airlines'},
#                  'flight': {'iataNumber': 'aa2363',
#                             'icaoNumber': 'aal2363',
#                             'number': '2363'}},
#   'departure': {'actualRunway': '2020-08-13T09:21:00.000',
#                 'actualTime': '2020-08-13T09:21:00.000',
#                 'baggage': None,
#                 'delay': '17',
#                 'estimatedRunway': '2020-08-13T09:21:00.000',
#                 'estimatedTime': '2020-08-13T09:24:00.000',
#                 'gate': 'A16',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T09:05:00.000',
#                 'terminal': 'A'},
#   'flight': {'iataNumber': 'AS4479', 'icaoNumber': 'ASA4479', 'number': '4479'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'AA', 'icaoCode': 'AAL', 'name': 'American Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-13T10:51:00.000',
#               'gate': 'C10',
#               'iataCode': 'BNA',
#               'icaoCode': 'KBNA',
#               'scheduledTime': '2020-08-13T11:03:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': '2020-08-13T09:21:00.000',
#                 'actualTime': '2020-08-13T09:21:00.000',
#                 'baggage': None,
#                 'delay': '17',
#                 'estimatedRunway': '2020-08-13T09:21:00.000',
#                 'estimatedTime': '2020-08-13T09:24:00.000',
#                 'gate': 'A16',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T09:05:00.000',
#                 'terminal': 'A'},
#   'flight': {'iataNumber': 'AA2363', 'icaoNumber': 'AAL2363', 'number': '2363'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'AS', 'icaoCode': 'ASA', 'name': 'Alaska Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': '1',
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-13T10:10:00.000',
#               'gate': '7',
#               'iataCode': 'SNA',
#               'icaoCode': 'KSNA',
#               'scheduledTime': '2020-08-13T10:15:00.000',
#               'terminal': 'A'},
#   'codeshared': {'airline': {'iataCode': 'aa',
#                              'icaoCode': 'aal',
#                              'name': 'american airlines'},
#                  'flight': {'iataNumber': 'aa2613',
#                             'icaoNumber': 'aal2613',
#                             'number': '2613'}},
#   'departure': {'actualRunway': '2020-08-13T09:31:00.000',
#                 'actualTime': '2020-08-13T09:31:00.000',
#                 'baggage': None,
#                 'delay': '26',
#                 'estimatedRunway': '2020-08-13T09:31:00.000',
#                 'estimatedTime': '2020-08-13T09:21:00.000',
#                 'gate': 'E2',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T09:05:00.000',
#                 'terminal': 'E'},
#   'flight': {'iataNumber': 'AS4321', 'icaoNumber': 'ASA4321', 'number': '4321'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'AA', 'icaoCode': 'AAL', 'name': 'American Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': '1',
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-13T10:10:00.000',
#               'gate': '7',
#               'iataCode': 'SNA',
#               'icaoCode': 'KSNA',
#               'scheduledTime': '2020-08-13T10:15:00.000',
#               'terminal': 'A'},
#   'codeshared': None,
#   'departure': {'actualRunway': '2020-08-13T09:31:00.000',
#                 'actualTime': '2020-08-13T09:31:00.000',
#                 'baggage': None,
#                 'delay': '26',
#                 'estimatedRunway': '2020-08-13T09:31:00.000',
#                 'estimatedTime': '2020-08-13T09:21:00.000',
#                 'gate': 'E2',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T09:05:00.000',
#                 'terminal': 'E'},
#   'flight': {'iataNumber': 'AA2613', 'icaoNumber': 'AAL2613', 'number': '2613'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'AS', 'icaoCode': 'ASA', 'name': 'Alaska Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-13T10:49:00.000',
#               'gate': 'C12',
#               'iataCode': 'STL',
#               'icaoCode': 'KSTL',
#               'scheduledTime': '2020-08-13T11:01:00.000',
#               'terminal': '1'},
#   'codeshared': {'airline': {'iataCode': 'aa',
#                              'icaoCode': 'aal',
#                              'name': 'american airlines'},
#                  'flight': {'iataNumber': 'aa3327',
#                             'icaoNumber': 'aal3327',
#                             'number': '3327'}},
#   'departure': {'actualRunway': '2020-08-13T09:25:00.000',
#                 'actualTime': '2020-08-13T09:25:00.000',
#                 'baggage': None,
#                 'delay': '21',
#                 'estimatedRunway': '2020-08-13T09:25:00.000',
#                 'estimatedTime': '2020-08-13T09:34:00.000',
#                 'gate': 'B48',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T09:05:00.000',
#                 'terminal': 'B'},
#   'flight': {'iataNumber': 'AS6036', 'icaoNumber': 'ASA6036', 'number': '6036'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'AA', 'icaoCode': 'AAL', 'name': 'American Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-13T10:49:00.000',
#               'gate': 'C12',
#               'iataCode': 'STL',
#               'icaoCode': 'KSTL',
#               'scheduledTime': '2020-08-13T11:01:00.000',
#               'terminal': '1'},
#   'codeshared': None,
#   'departure': {'actualRunway': '2020-08-13T09:25:00.000',
#                 'actualTime': '2020-08-13T09:25:00.000',
#                 'baggage': None,
#                 'delay': '21',
#                 'estimatedRunway': '2020-08-13T09:25:00.000',
#                 'estimatedTime': '2020-08-13T09:34:00.000',
#                 'gate': 'B48',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T09:05:00.000',
#                 'terminal': 'B'},
#   'flight': {'iataNumber': 'AA3327', 'icaoNumber': 'AAL3327', 'number': '3327'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'AS', 'icaoCode': 'ASA', 'name': 'Alaska Airlines'},
#   'arrival': {'actualRunway': '2020-08-13T09:45:00.000',
#               'actualTime': '2020-08-13T09:45:00.000',
#               'baggage': '1',
#               'delay': None,
#               'estimatedRunway': '2020-08-13T09:45:00.000',
#               'estimatedTime': '2020-08-13T09:45:00.000',
#               'gate': '3',
#               'iataCode': 'GRK',
#               'icaoCode': 'KGRK',
#               'scheduledTime': '2020-08-13T10:04:00.000',
#               'terminal': None},
#   'codeshared': {'airline': {'iataCode': 'aa',
#                              'icaoCode': 'aal',
#                              'name': 'american airlines'},
#                  'flight': {'iataNumber': 'aa3900',
#                             'icaoNumber': 'aal3900',
#                             'number': '3900'}},
#   'departure': {'actualRunway': '2020-08-13T09:19:00.000',
#                 'actualTime': '2020-08-13T09:19:00.000',
#                 'baggage': None,
#                 'delay': '15',
#                 'estimatedRunway': '2020-08-13T09:19:00.000',
#                 'estimatedTime': '2020-08-13T09:19:00.000',
#                 'gate': 'B25',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T09:05:00.000',
#                 'terminal': 'B'},
#   'flight': {'iataNumber': 'AS4370', 'icaoNumber': 'ASA4370', 'number': '4370'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'AA', 'icaoCode': 'AAL', 'name': 'American Airlines'},
#   'arrival': {'actualRunway': '2020-08-13T09:45:00.000',
#               'actualTime': '2020-08-13T09:45:00.000',
#               'baggage': '1',
#               'delay': None,
#               'estimatedRunway': '2020-08-13T09:45:00.000',
#               'estimatedTime': '2020-08-13T09:45:00.000',
#               'gate': '3',
#               'iataCode': 'GRK',
#               'icaoCode': 'KGRK',
#               'scheduledTime': '2020-08-13T10:04:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': '2020-08-13T09:19:00.000',
#                 'actualTime': '2020-08-13T09:19:00.000',
#                 'baggage': None,
#                 'delay': '15',
#                 'estimatedRunway': '2020-08-13T09:19:00.000',
#                 'estimatedTime': '2020-08-13T09:19:00.000',
#                 'gate': 'B25',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T09:05:00.000',
#                 'terminal': 'B'},
#   'flight': {'iataNumber': 'AA3900', 'icaoNumber': 'AAL3900', 'number': '3900'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'AS', 'icaoCode': 'ASA', 'name': 'Alaska Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': '34',
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-13T11:16:00.000',
#               'gate': None,
#               'iataCode': 'YVR',
#               'icaoCode': 'CYVR',
#               'scheduledTime': '2020-08-13T11:36:00.000',
#               'terminal': 'I'},
#   'codeshared': {'airline': {'iataCode': 'aa',
#                              'icaoCode': 'aal',
#                              'name': 'american airlines'},
#                  'flight': {'iataNumber': 'aa1415',
#                             'icaoNumber': 'aal1415',
#                             'number': '1415'}},
#   'departure': {'actualRunway': '2020-08-13T09:29:00.000',
#                 'actualTime': '2020-08-13T09:29:00.000',
#                 'baggage': None,
#                 'delay': '22',
#                 'estimatedRunway': '2020-08-13T09:29:00.000',
#                 'estimatedTime': '2020-08-13T09:23:00.000',
#                 'gate': 'C16',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T09:07:00.000',
#                 'terminal': 'C'},
#   'flight': {'iataNumber': 'AS6299', 'icaoNumber': 'ASA6299', 'number': '6299'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'AA', 'icaoCode': 'AAL', 'name': 'American Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': '34',
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-13T11:16:00.000',
#               'gate': None,
#               'iataCode': 'YVR',
#               'icaoCode': 'CYVR',
#               'scheduledTime': '2020-08-13T11:36:00.000',
#               'terminal': 'I'},
#   'codeshared': None,
#   'departure': {'actualRunway': '2020-08-13T09:29:00.000',
#                 'actualTime': '2020-08-13T09:29:00.000',
#                 'baggage': None,
#                 'delay': '22',
#                 'estimatedRunway': '2020-08-13T09:29:00.000',
#                 'estimatedTime': '2020-08-13T09:23:00.000',
#                 'gate': 'C16',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T09:07:00.000',
#                 'terminal': 'C'},
#   'flight': {'iataNumber': 'AA1415', 'icaoNumber': 'AAL1415', 'number': '1415'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'AA', 'icaoCode': 'AAL', 'name': 'American Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': '2',
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-13T13:29:00.000',
#               'gate': '29',
#               'iataCode': 'LGA',
#               'icaoCode': 'KLGA',
#               'scheduledTime': '2020-08-13T13:45:00.000',
#               'terminal': 'B'},
#   'codeshared': None,
#   'departure': {'actualRunway': '2020-08-13T09:30:00.000',
#                 'actualTime': '2020-08-13T09:30:00.000',
#                 'baggage': None,
#                 'delay': '21',
#                 'estimatedRunway': '2020-08-13T09:30:00.000',
#                 'estimatedTime': '2020-08-13T09:41:00.000',
#                 'gate': 'A39',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T09:09:00.000',
#                 'terminal': 'A'},
#   'flight': {'iataNumber': 'AA1056', 'icaoNumber': 'AAL1056', 'number': '1056'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'AS', 'icaoCode': 'ASA', 'name': 'Alaska Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-13T10:40:00.000',
#               'gate': '8',
#               'iataCode': 'SJC',
#               'icaoCode': 'KSJC',
#               'scheduledTime': '2020-08-13T10:50:00.000',
#               'terminal': 'A'},
#   'codeshared': {'airline': {'iataCode': 'aa',
#                              'icaoCode': 'aal',
#                              'name': 'american airlines'},
#                  'flight': {'iataNumber': 'aa1113',
#                             'icaoNumber': 'aal1113',
#                             'number': '1113'}},
#   'departure': {'actualRunway': '2020-08-13T09:32:00.000',
#                 'actualTime': '2020-08-13T09:32:00.000',
#                 'baggage': None,
#                 'delay': '23',
#                 'estimatedRunway': '2020-08-13T09:32:00.000',
#                 'estimatedTime': '2020-08-13T09:28:00.000',
#                 'gate': 'A33',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T09:10:00.000',
#                 'terminal': 'A'},
#   'flight': {'iataNumber': 'AS6273', 'icaoNumber': 'ASA6273', 'number': '6273'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'AA', 'icaoCode': 'AAL', 'name': 'American Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-13T10:40:00.000',
#               'gate': '8',
#               'iataCode': 'SJC',
#               'icaoCode': 'KSJC',
#               'scheduledTime': '2020-08-13T10:50:00.000',
#               'terminal': 'A'},
#   'codeshared': None,
#   'departure': {'actualRunway': '2020-08-13T09:32:00.000',
#                 'actualTime': '2020-08-13T09:32:00.000',
#                 'baggage': None,
#                 'delay': '23',
#                 'estimatedRunway': '2020-08-13T09:32:00.000',
#                 'estimatedTime': '2020-08-13T09:28:00.000',
#                 'gate': 'A33',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T09:10:00.000',
#                 'terminal': 'A'},
#   'flight': {'iataNumber': 'AA1113', 'icaoNumber': 'AAL1113', 'number': '1113'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': '9X',
#               'icaoCode': 'FDY',
#               'name': 'Southern Airways Express'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-13T10:45:00.000',
#               'gate': None,
#               'iataCode': 'ELD',
#               'icaoCode': 'KELD',
#               'scheduledTime': '2020-08-13T11:00:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': '2020-08-13T09:19:00.000',
#                 'actualTime': '2020-08-13T09:19:00.000',
#                 'baggage': None,
#                 'delay': '10',
#                 'estimatedRunway': '2020-08-13T09:19:00.000',
#                 'estimatedTime': '2020-08-13T09:19:00.000',
#                 'gate': None,
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T09:10:00.000',
#                 'terminal': None},
#   'flight': {'iataNumber': '9X423', 'icaoNumber': 'FDY423', 'number': '423'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'AA', 'icaoCode': 'AAL', 'name': 'American Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': '2',
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-13T11:06:00.000',
#               'gate': '5',
#               'iataCode': 'CID',
#               'icaoCode': 'KCID',
#               'scheduledTime': '2020-08-13T11:19:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': '2020-08-13T09:26:00.000',
#                 'actualTime': '2020-08-13T09:26:00.000',
#                 'baggage': None,
#                 'delay': '15',
#                 'estimatedRunway': '2020-08-13T09:26:00.000',
#                 'estimatedTime': '2020-08-13T09:36:00.000',
#                 'gate': 'B1',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T09:12:00.000',
#                 'terminal': 'B'},
#   'flight': {'iataNumber': 'AA3506', 'icaoNumber': 'AAL3506', 'number': '3506'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': '5X', 'icaoCode': 'UPS', 'name': 'UPS Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': '9',
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-13T12:14:00.000',
#               'gate': None,
#               'iataCode': 'SDF',
#               'icaoCode': 'KSDF',
#               'scheduledTime': '2020-08-13T12:06:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': '2020-08-13T09:39:00.000',
#                 'actualTime': '2020-08-13T09:39:00.000',
#                 'baggage': None,
#                 'delay': '26',
#                 'estimatedRunway': '2020-08-13T09:39:00.000',
#                 'estimatedTime': '2020-08-13T09:37:00.000',
#                 'gate': None,
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T09:13:00.000',
#                 'terminal': None},
#   'flight': {'iataNumber': '5X5509', 'icaoNumber': 'UPS5509', 'number': '5509'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'AA', 'icaoCode': 'AAL', 'name': 'American Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-13T10:27:00.000',
#               'gate': '14',
#               'iataCode': 'FAT',
#               'icaoCode': 'KFAT',
#               'scheduledTime': '2020-08-13T10:41:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': '2020-08-13T09:34:00.000',
#                 'actualTime': '2020-08-13T09:34:00.000',
#                 'baggage': None,
#                 'delay': '21',
#                 'estimatedRunway': '2020-08-13T09:34:00.000',
#                 'estimatedTime': '2020-08-13T09:35:00.000',
#                 'gate': 'A25',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T09:14:00.000',
#                 'terminal': 'A'},
#   'flight': {'iataNumber': 'AA2225', 'icaoNumber': 'AAL2225', 'number': '2225'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'AA', 'icaoCode': 'AAL', 'name': 'American Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': None,
#               'gate': None,
#               'iataCode': 'STS',
#               'icaoCode': 'KSTS',
#               'scheduledTime': '2020-08-13T11:12:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': None,
#                 'actualTime': None,
#                 'baggage': None,
#                 'delay': None,
#                 'estimatedRunway': None,
#                 'estimatedTime': None,
#                 'gate': None,
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T09:15:00.000',
#                 'terminal': None},
#   'flight': {'iataNumber': 'AA3677', 'icaoNumber': 'AAL3677', 'number': '3677'},
#   'status': 'cancelled',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'AC', 'icaoCode': 'ACA', 'name': 'Air Canada'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': '16',
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-13T10:10:00.000',
#               'gate': 'B18',
#               'iataCode': 'DEN',
#               'icaoCode': 'KDEN',
#               'scheduledTime': '2020-08-13T10:23:00.000',
#               'terminal': None},
#   'codeshared': {'airline': {'iataCode': 'ua',
#                              'icaoCode': 'ual',
#                              'name': 'united airlines'},
#                  'flight': {'iataNumber': 'ua1532',
#                             'icaoNumber': 'ual1532',
#                             'number': '1532'}},
#   'departure': {'actualRunway': '2020-08-13T09:39:00.000',
#                 'actualTime': '2020-08-13T09:39:00.000',
#                 'baggage': None,
#                 'delay': '23',
#                 'estimatedRunway': '2020-08-13T09:39:00.000',
#                 'estimatedTime': '2020-08-13T09:22:00.000',
#                 'gate': 'E8',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T09:16:00.000',
#                 'terminal': 'E'},
#   'flight': {'iataNumber': 'AC5629', 'icaoNumber': 'ACA5629', 'number': '5629'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'UA', 'icaoCode': 'UAL', 'name': 'United Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': '16',
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-13T10:10:00.000',
#               'gate': 'B18',
#               'iataCode': 'DEN',
#               'icaoCode': 'KDEN',
#               'scheduledTime': '2020-08-13T10:23:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': '2020-08-13T09:39:00.000',
#                 'actualTime': '2020-08-13T09:39:00.000',
#                 'baggage': None,
#                 'delay': '23',
#                 'estimatedRunway': '2020-08-13T09:39:00.000',
#                 'estimatedTime': '2020-08-13T09:22:00.000',
#                 'gate': 'E8',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T09:16:00.000',
#                 'terminal': 'E'},
#   'flight': {'iataNumber': 'UA1532', 'icaoNumber': 'UAL1532', 'number': '1532'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'AS', 'icaoCode': 'ASA', 'name': 'Alaska Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-13T12:36:00.000',
#               'gate': 'B9',
#               'iataCode': 'CHS',
#               'icaoCode': 'KCHS',
#               'scheduledTime': '2020-08-13T13:03:00.000',
#               'terminal': None},
#   'codeshared': {'airline': {'iataCode': 'aa',
#                              'icaoCode': 'aal',
#                              'name': 'american airlines'},
#                  'flight': {'iataNumber': 'aa3344',
#                             'icaoNumber': 'aal3344',
#                             'number': '3344'}},
#   'departure': {'actualRunway': '2020-08-13T09:27:00.000',
#                 'actualTime': '2020-08-13T09:27:00.000',
#                 'baggage': None,
#                 'delay': '10',
#                 'estimatedRunway': '2020-08-13T09:27:00.000',
#                 'estimatedTime': '2020-08-13T09:40:00.000',
#                 'gate': 'B17',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T09:18:00.000',
#                 'terminal': 'B'},
#   'flight': {'iataNumber': 'AS4789', 'icaoNumber': 'ASA4789', 'number': '4789'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'BA', 'icaoCode': 'BAW', 'name': 'British Airways'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-13T12:36:00.000',
#               'gate': 'B9',
#               'iataCode': 'CHS',
#               'icaoCode': 'KCHS',
#               'scheduledTime': '2020-08-13T13:03:00.000',
#               'terminal': None},
#   'codeshared': {'airline': {'iataCode': 'aa',
#                              'icaoCode': 'aal',
#                              'name': 'american airlines'},
#                  'flight': {'iataNumber': 'aa3344',
#                             'icaoNumber': 'aal3344',
#                             'number': '3344'}},
#   'departure': {'actualRunway': '2020-08-13T09:27:00.000',
#                 'actualTime': '2020-08-13T09:27:00.000',
#                 'baggage': None,
#                 'delay': '10',
#                 'estimatedRunway': '2020-08-13T09:27:00.000',
#                 'estimatedTime': '2020-08-13T09:40:00.000',
#                 'gate': 'B17',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T09:18:00.000',
#                 'terminal': 'B'},
#   'flight': {'iataNumber': 'BA4769', 'icaoNumber': 'BAW4769', 'number': '4769'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'AA', 'icaoCode': 'AAL', 'name': 'American Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-13T12:36:00.000',
#               'gate': 'B9',
#               'iataCode': 'CHS',
#               'icaoCode': 'KCHS',
#               'scheduledTime': '2020-08-13T13:03:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': '2020-08-13T09:27:00.000',
#                 'actualTime': '2020-08-13T09:27:00.000',
#                 'baggage': None,
#                 'delay': '10',
#                 'estimatedRunway': '2020-08-13T09:27:00.000',
#                 'estimatedTime': '2020-08-13T09:40:00.000',
#                 'gate': 'B17',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T09:18:00.000',
#                 'terminal': 'B'},
#   'flight': {'iataNumber': 'AA3344', 'icaoNumber': 'AAL3344', 'number': '3344'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': '9X',
#               'icaoCode': 'FDY',
#               'name': 'Southern Airways Express'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': '21',
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-13T11:40:00.000',
#               'gate': None,
#               'iataCode': 'HRO',
#               'icaoCode': 'KHRO',
#               'scheduledTime': '2020-08-13T11:20:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': '2020-08-13T09:58:00.000',
#                 'actualTime': '2020-08-13T09:58:00.000',
#                 'baggage': None,
#                 'delay': '39',
#                 'estimatedRunway': '2020-08-13T09:58:00.000',
#                 'estimatedTime': '2020-08-13T09:50:00.000',
#                 'gate': None,
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T09:20:00.000',
#                 'terminal': None},
#   'flight': {'iataNumber': '9X405', 'icaoNumber': 'FDY405', 'number': '405'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'AA', 'icaoCode': 'AAL', 'name': 'American Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-13T11:27:00.000',
#               'gate': 'K19',
#               'iataCode': 'ORD',
#               'icaoCode': 'KORD',
#               'scheduledTime': '2020-08-13T12:04:00.000',
#               'terminal': '3'},
#   'codeshared': None,
#   'departure': {'actualRunway': '2020-08-13T09:38:00.000',
#                 'actualTime': '2020-08-13T09:38:00.000',
#                 'baggage': None,
#                 'delay': '8',
#                 'estimatedRunway': '2020-08-13T09:38:00.000',
# ...
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T21:00:00.000',
#                 'terminal': 'E'},
#   'flight': {'iataNumber': 'AA3982', 'icaoNumber': 'AAL3982', 'number': '3982'},
#   'status': 'scheduled',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'AA', 'icaoCode': 'AAL', 'name': 'American Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': '1',
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': None,
#               'gate': '1',
#               'iataCode': 'MHK',
#               'icaoCode': 'KMHK',
#               'scheduledTime': '2020-08-13T22:35:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': None,
#                 'actualTime': None,
#                 'baggage': None,
#                 'delay': '20',
#                 'estimatedRunway': None,
#                 'estimatedTime': '2020-08-13T21:25:00.000',
#                 'gate': 'B21',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T21:05:00.000',
#                 'terminal': 'B'},
#   'flight': {'iataNumber': 'AA3523', 'icaoNumber': 'AAL3523', 'number': '3523'},
#   'status': 'scheduled',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'AA', 'icaoCode': 'AAL', 'name': 'American Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': '2',
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': None,
#               'gate': '3',
#               'iataCode': 'MOB',
#               'icaoCode': 'KMOB',
#               'scheduledTime': '2020-08-13T22:46:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': None,
#                 'actualTime': None,
#                 'baggage': None,
#                 'delay': '20',
#                 'estimatedRunway': None,
#                 'estimatedTime': '2020-08-13T21:25:00.000',
#                 'gate': 'B33',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T21:05:00.000',
#                 'terminal': 'B'},
#   'flight': {'iataNumber': 'AA5841', 'icaoNumber': 'AAL5841', 'number': '5841'},
#   'status': 'scheduled',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'AA', 'icaoCode': 'AAL', 'name': 'American Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': '2',
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': None,
#               'gate': '27',
#               'iataCode': 'IAH',
#               'icaoCode': 'KIAH',
#               'scheduledTime': '2020-08-13T22:18:00.000',
#               'terminal': 'A'},
#   'codeshared': None,
#   'departure': {'actualRunway': None,
#                 'actualTime': None,
#                 'baggage': None,
#                 'delay': '16',
#                 'estimatedRunway': None,
#                 'estimatedTime': '2020-08-13T21:22:00.000',
#                 'gate': 'E2',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T21:06:00.000',
#                 'terminal': 'E'},
#   'flight': {'iataNumber': 'AA2694', 'icaoNumber': 'AAL2694', 'number': '2694'},
#   'status': 'scheduled',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'AA', 'icaoCode': 'AAL', 'name': 'American Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': None,
#               'gate': 'A2',
#               'iataCode': 'ELP',
#               'icaoCode': 'KELP',
#               'scheduledTime': '2020-08-13T21:47:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': None,
#                 'actualTime': None,
#                 'baggage': None,
#                 'delay': '20',
#                 'estimatedRunway': None,
#                 'estimatedTime': '2020-08-13T21:29:00.000',
#                 'gate': 'B25',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T21:09:00.000',
#                 'terminal': 'B'},
#   'flight': {'iataNumber': 'AA5845', 'icaoNumber': 'AAL5845', 'number': '5845'},
#   'status': 'scheduled',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'AA', 'icaoCode': 'AAL', 'name': 'American Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': '1',
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': None,
#               'gate': '2',
#               'iataCode': 'JLN',
#               'icaoCode': 'KJLN',
#               'scheduledTime': '2020-08-13T22:36:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': None,
#                 'actualTime': None,
#                 'baggage': None,
#                 'delay': '20',
#                 'estimatedRunway': None,
#                 'estimatedTime': '2020-08-13T21:30:00.000',
#                 'gate': 'E22',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T21:10:00.000',
#                 'terminal': 'E'},
#   'flight': {'iataNumber': 'AA3461', 'icaoNumber': 'AAL3461', 'number': '3461'},
#   'status': 'scheduled',
#   'type': 'departure'},
#  {'airline': {'iataCode': '5X', 'icaoCode': 'UPS', 'name': 'UPS Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': None,
#               'gate': None,
#               'iataCode': 'SDF',
#               'icaoCode': 'KSDF',
#               'scheduledTime': '2020-08-14T00:05:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': None,
#                 'actualTime': None,
#                 'baggage': None,
#                 'delay': None,
#                 'estimatedRunway': None,
#                 'estimatedTime': None,
#                 'gate': None,
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T21:14:00.000',
#                 'terminal': None},
#   'flight': {'iataNumber': '5X765', 'icaoNumber': 'UPS765', 'number': '765'},
#   'status': 'scheduled',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'FX', 'icaoCode': 'FDX', 'name': 'FedEx'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': None,
#               'gate': None,
#               'iataCode': 'MEM',
#               'icaoCode': 'KMEM',
#               'scheduledTime': '2020-08-13T22:56:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': None,
#                 'actualTime': None,
#                 'baggage': None,
#                 'delay': '15',
#                 'estimatedRunway': None,
#                 'estimatedTime': '2020-08-13T21:53:00.000',
#                 'gate': None,
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T21:38:00.000',
#                 'terminal': None},
#   'flight': {'iataNumber': 'FX1201', 'icaoNumber': 'FDX1201', 'number': '1201'},
#   'status': 'scheduled',
#   'type': 'departure'},
#  {'airline': {'iataCode': '5X', 'icaoCode': 'UPS', 'name': 'UPS Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': None,
#               'gate': None,
#               'iataCode': 'SDF',
#               'icaoCode': 'KSDF',
#               'scheduledTime': '2020-08-14T00:35:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': None,
#                 'actualTime': None,
#                 'baggage': None,
#                 'delay': None,
#                 'estimatedRunway': None,
#                 'estimatedTime': None,
#                 'gate': None,
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T21:44:00.000',
#                 'terminal': None},
#   'flight': {'iataNumber': '5X767', 'icaoNumber': 'UPS767', 'number': '767'},
#   'status': 'scheduled',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'QR', 'icaoCode': 'QTR', 'name': 'Qatar Airways'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': None,
#               'gate': None,
#               'iataCode': 'LUX',
#               'icaoCode': 'ELLX',
#               'scheduledTime': '2020-08-14T14:30:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': None,
#                 'actualTime': None,
#                 'baggage': None,
#                 'delay': '10',
#                 'estimatedRunway': None,
#                 'estimatedTime': '2020-08-13T22:05:00.000',
#                 'gate': None,
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T21:55:00.000',
#                 'terminal': None},
#   'flight': {'iataNumber': 'QR8132', 'icaoNumber': 'QTR8132', 'number': '8132'},
#   'status': 'scheduled',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'FX', 'icaoCode': 'FDX', 'name': 'FedEx'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': None,
#               'gate': None,
#               'iataCode': 'IND',
#               'icaoCode': 'KIND',
#               'scheduledTime': '2020-08-14T00:48:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': None,
#                 'actualTime': None,
#                 'baggage': None,
#                 'delay': '14',
#                 'estimatedRunway': None,
#                 'estimatedTime': '2020-08-13T22:09:00.000',
#                 'gate': None,
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T21:55:00.000',
#                 'terminal': None},
#   'flight': {'iataNumber': 'FX1609', 'icaoNumber': 'FDX1609', 'number': '1609'},
#   'status': 'scheduled',
#   'type': 'departure'},
#  {'airline': {'iataCode': '5X', 'icaoCode': 'UPS', 'name': 'UPS Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': None,
#               'gate': None,
#               'iataCode': 'RFD',
#               'icaoCode': 'KRFD',
#               'scheduledTime': '2020-08-13T23:59:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': None,
#                 'actualTime': None,
#                 'baggage': None,
#                 'delay': None,
#                 'estimatedRunway': None,
#                 'estimatedTime': None,
#                 'gate': None,
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T22:10:00.000',
#                 'terminal': None},
#   'flight': {'iataNumber': '5X753', 'icaoNumber': 'UPS753', 'number': '753'},
#   'status': 'scheduled',
#   'type': 'departure'},
#  {'airline': {'iataCode': '5X', 'icaoCode': 'UPS', 'name': 'UPS Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': None,
#               'gate': None,
#               'iataCode': 'SDF',
#               'icaoCode': 'KSDF',
#               'scheduledTime': '2020-08-14T01:09:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': None,
#                 'actualTime': None,
#                 'baggage': None,
#                 'delay': None,
#                 'estimatedRunway': None,
#                 'estimatedTime': None,
#                 'gate': None,
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T22:16:00.000',
#                 'terminal': None},
#   'flight': {'iataNumber': '5X793', 'icaoNumber': 'UPS793', 'number': '793'},
#   'status': 'scheduled',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'K4', 'icaoCode': 'CKS', 'name': 'Kalitta Air'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': None,
#               'gate': None,
#               'iataCode': 'CVG',
#               'icaoCode': 'KCVG',
#               'scheduledTime': '2020-08-14T01:30:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': None,
#                 'actualTime': None,
#                 'baggage': None,
#                 'delay': None,
#                 'estimatedRunway': None,
#                 'estimatedTime': None,
#                 'gate': None,
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T22:30:00.000',
#                 'terminal': None},
#   'flight': {'iataNumber': 'K4102', 'icaoNumber': 'CKS102', 'number': '102'},
#   'status': 'scheduled',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'FX', 'icaoCode': 'FDX', 'name': 'FedEx'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': None,
#               'gate': None,
#               'iataCode': 'IND',
#               'icaoCode': 'KIND',
#               'scheduledTime': '2020-08-14T01:32:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': None,
#                 'actualTime': None,
#                 'baggage': None,
#                 'delay': '14',
#                 'estimatedRunway': None,
#                 'estimatedTime': '2020-08-13T22:53:00.000',
#                 'gate': None,
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T22:39:00.000',
#                 'terminal': None},
#   'flight': {'iataNumber': 'FX1601', 'icaoNumber': 'FDX1601', 'number': '1601'},
#   'status': 'scheduled',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'FX', 'icaoCode': 'FDX', 'name': 'FedEx'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': None,
#               'gate': None,
#               'iataCode': 'MEM',
#               'icaoCode': 'KMEM',
#               'scheduledTime': '2020-08-14T00:16:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': None,
#                 'actualTime': None,
#                 'baggage': None,
#                 'delay': '16',
#                 'estimatedRunway': None,
#                 'estimatedTime': '2020-08-13T23:11:00.000',
#                 'gate': None,
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-13T22:55:00.000',
#                 'terminal': None},
#   'flight': {'iataNumber': 'FX1365', 'icaoNumber': 'FDX1365', 'number': '1365'},
#   'status': 'scheduled',
#   'type': 'departure'}]

# %%
#JB-added terminal to the list which will give us another lookup option
names= []
times= []
flights=[]
terminal= []
length = int(len(data)-1)

for x in range(0,length):
    names.append(data[x]["airline"]["name"])
    Time = data[x]["departure"]["scheduledTime"]
    TimeSplit = Time.split("T")[1]
    times.append(TimeSplit[:5])
    flights.append(data[x]["flight"]["iataNumber"])
    terminal.append(data[x]["departure"]["terminal"])
df = pd.DataFrame()
df["name"] =names
df["scheduledTime"] =pd.to_datetime(times)
df["iataNumber"]=flights
df["Terminal"]=terminal

df
# Out:
#                    name       scheduledTime iataNumber Terminal
# 0     American Airlines 2020-08-13 09:00:00     AA2420        C
# 1     American Airlines 2020-08-13 09:00:00     AA2810        C
# 2     American Airlines 2020-08-13 09:00:00     AA3333        B
# 3       Alaska Airlines 2020-08-13 09:00:00     AS4005        B
# 4     American Airlines 2020-08-13 09:00:00     AA5751        B
# ...                 ...                 ...        ...      ...
# 1122              FedEx 2020-08-13 21:55:00     FX1609     None
# 1123       UPS Airlines 2020-08-13 22:10:00      5X753     None
# 1124       UPS Airlines 2020-08-13 22:16:00      5X793     None
# 1125        Kalitta Air 2020-08-13 22:30:00      K4102     None
# 1126              FedEx 2020-08-13 22:39:00     FX1601     None
#
# [1127 rows x 4 columns]

# %%
# Playing around with time
# '2020-08-13 06:00:00'
# Original code
# time_df = df["scheduledTime"] =pd.to_datetime(times, format="%b %d %Y %I:%M %p")
# Match the code to time
# time_df = df["scheduledTime"] =pd.to_datetime(times, format="%b %d %Y %I:%M %p")
# from datetime import datetime
# d = datetime.striptime("")

# import time
# t = time.strptime(time_df, "%H:%M")
# timevalue_12hour = time.strftime("%I:%M %p", t)

# t = time.strptime(time_df, "%H:%M")
# timevalue_12hour = time.strftime("%I:%M %p", t)

# date_time = time.strftime("%b %d %Y %-I:%M %p")
# date_time
time_df = df["scheduledTime"]
time_fixed = time_df.map(lambda x: x.strftime("%b %d %Y %I:%M %p"))
time_fixed
# Out:
# 0       Aug 13 2020 09:00 AM
# 1       Aug 13 2020 09:00 AM
# 2       Aug 13 2020 09:00 AM
# 3       Aug 13 2020 09:00 AM
# 4       Aug 13 2020 09:00 AM
#                 ...
# 1122    Aug 13 2020 09:55 PM
# 1123    Aug 13 2020 10:10 PM
# 1124    Aug 13 2020 10:16 PM
# 1125    Aug 13 2020 10:30 PM
# 1126    Aug 13 2020 10:39 PM
# Name: scheduledTime, Length: 1127, dtype: object

# %%
time_df = df["scheduledTime"] =pd.to_datetime(times)

time_df
# Out:
# DatetimeIndex(['2020-08-13 09:00:00', '2020-08-13 09:00:00',
#                '2020-08-13 09:00:00', '2020-08-13 09:00:00',
#                '2020-08-13 09:00:00', '2020-08-13 09:00:00',
#                '2020-08-13 09:00:00', '2020-08-13 09:00:00',
#                '2020-08-13 09:00:00', '2020-08-13 09:00:00',
#                ...
#                '2020-08-13 21:10:00', '2020-08-13 21:14:00',
#                '2020-08-13 21:38:00', '2020-08-13 21:44:00',
#                '2020-08-13 21:55:00', '2020-08-13 21:55:00',
#                '2020-08-13 22:10:00', '2020-08-13 22:16:00',
#                '2020-08-13 22:30:00', '2020-08-13 22:39:00'],
#               dtype='datetime64[ns]', length=1127, freq=None)

# %%
#df.to_csv("airport_data.csv", encoding="utf-8", index=False, header=True)
test = df.groupby(["scheduledTime"])["iataNumber"].count()
# Convert to DataFrame
test_df = test.to_frame()
test_df
# Out:
#                      iataNumber
# scheduledTime
# 2020-08-13 09:00:00          11
# 2020-08-13 09:01:00           1
# 2020-08-13 09:05:00          10
# 2020-08-13 09:07:00           2
# 2020-08-13 09:09:00           1
# ...                         ...
# 2020-08-13 21:55:00           2
# 2020-08-13 22:10:00           1
# 2020-08-13 22:16:00           1
# 2020-08-13 22:30:00           1
# 2020-08-13 22:39:00           1
#
# [241 rows x 1 columns]

# %%
#df.to_csv("airport_data.csv", encoding="utf-8", index=False, header=True)
test = df.groupby(["scheduledTime"])["iataNumber"].count()
test.plot(kind="line", color="green", title="Flight per Hour", fontsize=20, figsize = (40,10))
plt.xlabel("Schedule Time", fontsize=30)
plt.ylabel("Number of Flights", fontsize=30)
plt.title("Flight per Hour", fontsize=40)
plt.xlim("2020-08-13 09:00:00","2020-08-13 23:00:00")

# x_axis = np.arange(test_df)
# tick_locations = [value for value in x_axis]
# xticks=["midnight","3am","6am","9am","noon","3pm","6pm","9pm","midnight"]
# plt.xticks(tick_locations, test_df["scheduledTime"])

# np.arange(np.datetime64("2020-08-13 06:00:00"), np.datetime64("2020-08-13 18:00:00"))
# Out:
# (737650.375, 737650.9583333334)

# %%
# Graph change with time
# This graph looks different from the original
#df.to_csv("airport_data.csv", encoding="utf-8", index=False, header=True)
test = df.groupby(["scheduledTime"])["iataNumber"].count()
test.plot(kind="line", title="Flight per Hour", figsize = (20,10))
plt.xlim("2020-08-13 09:00:00","2020-08-13 23:00:00")
#xticks=["midnight","3am","6am","9am","noon","3pm","6pm","9pm","midnight"]
# Out:
# (737650.375, 737650.9583333334)
