# %%
import pandas as pd
import requests
import json
from config import api_key
from pprint import pprint
import matplotlib.pyplot as plt
import csv
import datetime

# %%
Departure_url = f"http://aviation-edge.com/v2/public/timetable?key={api_key}&iataCode=DFW&type=departure"
#Arrival_url = f"http://aviation-edge.com/v2/public/timetable?key={api_key}&&iataCode=DFW&type=arrival"

# %%
# Performing a GET request similar to the one we executed
# earlier
data = requests.get(Departure_url).json()
#responseA = requests.get(Arrival_url)
pprint(data)
# Out:
# [{'airline': {'iataCode': '5X', 'icaoCode': 'UPS', 'name': 'UPS Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': '11',
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-12T06:05:00.000',
#               'gate': None,
#               'iataCode': 'MIA',
#               'icaoCode': 'KMIA',
#               'scheduledTime': '2020-08-12T05:55:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': '2020-08-12T02:46:00.000',
#                 'actualTime': '2020-08-12T02:46:00.000',
#                 'baggage': None,
#                 'delay': '24',
#                 'estimatedRunway': '2020-08-12T02:46:00.000',
#                 'estimatedTime': '2020-08-12T02:46:00.000',
#                 'gate': None,
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-12T02:22:00.000',
#                 'terminal': None},
#   'flight': {'iataNumber': '5X1344', 'icaoNumber': 'UPS1344', 'number': '1344'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': '5X', 'icaoCode': 'UPS', 'name': 'UPS Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-12T05:40:00.000',
#               'gate': None,
#               'iataCode': 'TPA',
#               'icaoCode': 'KTPA',
#               'scheduledTime': '2020-08-12T05:44:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': '2020-08-12T02:42:00.000',
#                 'actualTime': '2020-08-12T02:42:00.000',
#                 'baggage': None,
#                 'delay': '20',
#                 'estimatedRunway': '2020-08-12T02:42:00.000',
#                 'estimatedTime': '2020-08-12T02:38:00.000',
#                 'gate': None,
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-12T02:22:00.000',
#                 'terminal': None},
#   'flight': {'iataNumber': '5X1350', 'icaoNumber': 'UPS1350', 'number': '1350'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': '5X', 'icaoCode': 'UPS', 'name': 'UPS Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': '32',
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-12T04:48:00.000',
#               'gate': None,
#               'iataCode': 'ORD',
#               'icaoCode': 'KORD',
#               'scheduledTime': '2020-08-12T04:17:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': '2020-08-12T03:06:00.000',
#                 'actualTime': '2020-08-12T03:06:00.000',
#                 'baggage': None,
#                 'delay': '41',
#                 'estimatedRunway': '2020-08-12T03:06:00.000',
#                 'estimatedTime': '2020-08-12T03:01:00.000',
#                 'gate': None,
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-12T02:26:00.000',
#                 'terminal': None},
#   'flight': {'iataNumber': '5X608', 'icaoNumber': 'UPS608', 'number': '608'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': '5X', 'icaoCode': 'UPS', 'name': 'UPS Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': '4',
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-12T03:29:00.000',
#               'gate': None,
#               'iataCode': 'LBB',
#               'icaoCode': 'KLBB',
#               'scheduledTime': '2020-08-12T03:26:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': '2020-08-12T02:44:00.000',
#                 'actualTime': '2020-08-12T02:44:00.000',
#                 'baggage': None,
#                 'delay': '14',
#                 'estimatedRunway': '2020-08-12T02:44:00.000',
#                 'estimatedTime': '2020-08-12T02:44:00.000',
#                 'gate': None,
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-12T02:30:00.000',
#                 'terminal': None},
#   'flight': {'iataNumber': '5X860', 'icaoNumber': 'UPS860', 'number': '860'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': '5X', 'icaoCode': 'UPS', 'name': 'UPS Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': '32',
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-12T05:44:00.000',
#               'gate': None,
#               'iataCode': 'ATL',
#               'icaoCode': 'KATL',
#               'scheduledTime': '2020-08-12T05:13:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': '2020-08-12T03:09:00.000',
#                 'actualTime': '2020-08-12T03:09:00.000',
#                 'baggage': None,
#                 'delay': '37',
#                 'estimatedRunway': '2020-08-12T03:09:00.000',
#                 'estimatedTime': '2020-08-12T03:04:00.000',
#                 'gate': None,
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-12T02:32:00.000',
#                 'terminal': None},
#   'flight': {'iataNumber': '5X1302', 'icaoNumber': 'UPS1302', 'number': '1302'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': '5X', 'icaoCode': 'UPS', 'name': 'UPS Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': '7',
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-12T03:23:00.000',
#               'gate': None,
#               'iataCode': 'DEN',
#               'icaoCode': 'KDEN',
#               'scheduledTime': '2020-08-12T03:16:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': '2020-08-12T02:54:00.000',
#                 'actualTime': '2020-08-12T02:54:00.000',
#                 'baggage': None,
#                 'delay': '20',
#                 'estimatedRunway': '2020-08-12T02:54:00.000',
#                 'estimatedTime': '2020-08-12T02:53:00.000',
#                 'gate': None,
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-12T02:34:00.000',
#                 'terminal': None},
#   'flight': {'iataNumber': '5X804', 'icaoNumber': 'UPS804', 'number': '804'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': '5X', 'icaoCode': 'UPS', 'name': 'UPS Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': '8',
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-12T03:42:00.000',
#               'gate': None,
#               'iataCode': 'LIT',
#               'icaoCode': 'KLIT',
#               'scheduledTime': '2020-08-12T03:35:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': '2020-08-12T02:52:00.000',
#                 'actualTime': '2020-08-12T02:52:00.000',
#                 'baggage': None,
#                 'delay': '17',
#                 'estimatedRunway': '2020-08-12T02:52:00.000',
#                 'estimatedTime': '2020-08-12T02:56:00.000',
#                 'gate': None,
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-12T02:35:00.000',
#                 'terminal': None},
#   'flight': {'iataNumber': '5X1386', 'icaoNumber': 'UPS1386', 'number': '1386'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': '5X', 'icaoCode': 'UPS', 'name': 'UPS Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-12T06:01:00.000',
#               'gate': None,
#               'iataCode': 'MCO',
#               'icaoCode': 'KMCO',
#               'scheduledTime': '2020-08-12T06:02:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': '2020-08-12T03:02:00.000',
#                 'actualTime': '2020-08-12T03:02:00.000',
#                 'baggage': None,
#                 'delay': '22',
#                 'estimatedRunway': '2020-08-12T03:02:00.000',
#                 'estimatedTime': '2020-08-12T02:56:00.000',
#                 'gate': None,
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-12T02:40:00.000',
#                 'terminal': None},
#   'flight': {'iataNumber': '5X1336', 'icaoNumber': 'UPS1336', 'number': '1336'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': '5X', 'icaoCode': 'UPS', 'name': 'UPS Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': '6',
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-12T04:53:00.000',
#               'gate': None,
#               'iataCode': 'MSP',
#               'icaoCode': 'KMSP',
#               'scheduledTime': '2020-08-12T04:47:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': '2020-08-12T03:03:00.000',
#                 'actualTime': '2020-08-12T03:03:00.000',
#                 'baggage': None,
#                 'delay': '14',
#                 'estimatedRunway': '2020-08-12T03:03:00.000',
#                 'estimatedTime': '2020-08-12T03:06:00.000',
#                 'gate': None,
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-12T02:50:00.000',
#                 'terminal': None},
#   'flight': {'iataNumber': '5X562', 'icaoNumber': 'UPS562', 'number': '562'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': '5X', 'icaoCode': 'UPS', 'name': 'UPS Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-12T06:01:00.000',
#               'gate': None,
#               'iataCode': 'JAX',
#               'icaoCode': 'KJAX',
#               'scheduledTime': '2020-08-12T06:03:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': '2020-08-12T03:11:00.000',
#                 'actualTime': '2020-08-12T03:11:00.000',
#                 'baggage': None,
#                 'delay': '16',
#                 'estimatedRunway': '2020-08-12T03:11:00.000',
#                 'estimatedTime': '2020-08-12T03:13:00.000',
#                 'gate': None,
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-12T02:55:00.000',
#                 'terminal': None},
#   'flight': {'iataNumber': '5X1318', 'icaoNumber': 'UPS1318', 'number': '1318'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': '5X', 'icaoCode': 'UPS', 'name': 'UPS Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-12T03:33:00.000',
#               'gate': None,
#               'iataCode': 'ONT',
#               'icaoCode': 'KONT',
#               'scheduledTime': '2020-08-12T03:39:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': '2020-08-12T03:07:00.000',
#                 'actualTime': '2020-08-12T03:07:00.000',
#                 'baggage': None,
#                 'delay': '12',
#                 'estimatedRunway': '2020-08-12T03:07:00.000',
#                 'estimatedTime': '2020-08-12T03:03:00.000',
#                 'gate': None,
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-12T02:55:00.000',
#                 'terminal': None},
#   'flight': {'iataNumber': '5X930', 'icaoNumber': 'UPS930', 'number': '930'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'A8', 'icaoCode': 'AMF', 'name': 'Ameriflight'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-12T04:55:00.000',
#               'gate': None,
#               'iataCode': 'TUL',
#               'icaoCode': 'KTUL',
#               'scheduledTime': '2020-08-12T05:01:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': '2020-08-12T03:49:00.000',
#                 'actualTime': '2020-08-12T03:49:00.000',
#                 'baggage': None,
#                 'delay': '49',
#                 'estimatedRunway': '2020-08-12T03:49:00.000',
#                 'estimatedTime': '2020-08-12T03:38:00.000',
#                 'gate': None,
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-12T03:00:00.000',
#                 'terminal': None},
#   'flight': {'iataNumber': 'A81792', 'icaoNumber': 'AMF1792', 'number': '1792'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': '5X', 'icaoCode': 'UPS', 'name': 'UPS Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': '9',
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-12T04:40:00.000',
#               'gate': None,
#               'iataCode': 'SAT',
#               'icaoCode': 'KSAT',
#               'scheduledTime': '2020-08-12T04:31:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': '2020-08-12T04:01:00.000',
#                 'actualTime': '2020-08-12T04:01:00.000',
#                 'baggage': None,
#                 'delay': '21',
#                 'estimatedRunway': '2020-08-12T04:01:00.000',
#                 'estimatedTime': '2020-08-12T03:58:00.000',
#                 'gate': None,
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-12T03:40:00.000',
#                 'terminal': None},
#   'flight': {'iataNumber': '5X780', 'icaoNumber': 'UPS780', 'number': '780'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': '5X', 'icaoCode': 'UPS', 'name': 'UPS Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': '9',
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-12T04:52:00.000',
#               'gate': None,
#               'iataCode': 'IAH',
#               'icaoCode': 'KIAH',
#               'scheduledTime': '2020-08-12T04:43:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': '2020-08-12T04:03:00.000',
#                 'actualTime': '2020-08-12T04:03:00.000',
#                 'baggage': None,
#                 'delay': '14',
#                 'estimatedRunway': '2020-08-12T04:03:00.000',
#                 'estimatedTime': '2020-08-12T03:58:00.000',
#                 'gate': None,
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-12T03:50:00.000',
#                 'terminal': None},
#   'flight': {'iataNumber': '5X776', 'icaoNumber': 'UPS776', 'number': '776'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'A8', 'icaoCode': 'AMF', 'name': 'Ameriflight'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': '4',
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-12T05:27:00.000',
#               'gate': None,
#               'iataCode': 'LBB',
#               'icaoCode': 'KLBB',
#               'scheduledTime': '2020-08-12T05:23:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': '2020-08-12T04:14:00.000',
#                 'actualTime': '2020-08-12T04:14:00.000',
#                 'baggage': None,
#                 'delay': '15',
#                 'estimatedRunway': '2020-08-12T04:14:00.000',
#                 'estimatedTime': '2020-08-12T04:25:00.000',
#                 'gate': None,
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-12T04:00:00.000',
#                 'terminal': None},
#   'flight': {'iataNumber': 'A81746', 'icaoNumber': 'AMF1746', 'number': '1746'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'KE', 'icaoCode': 'KAL', 'name': 'Korean Air'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': None,
#               'gate': None,
#               'iataCode': 'GDL',
#               'icaoCode': 'MMGL',
#               'scheduledTime': '2020-08-12T05:45:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': None,
#                 'actualTime': None,
#                 'baggage': None,
#                 'delay': '15',
#                 'estimatedRunway': None,
#                 'estimatedTime': '2020-08-12T04:30:00.000',
#                 'gate': None,
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-12T04:15:00.000',
#                 'terminal': None},
#   'flight': {'iataNumber': 'KE277', 'icaoNumber': 'KAL277', 'number': '277'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'A8', 'icaoCode': 'AMF', 'name': 'Ameriflight'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': '4',
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-12T05:27:00.000',
#               'gate': None,
#               'iataCode': 'LBB',
#               'icaoCode': 'KLBB',
#               'scheduledTime': '2020-08-12T05:23:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': '2020-08-12T04:16:00.000',
#                 'actualTime': '2020-08-12T04:16:00.000',
#                 'baggage': None,
#                 'delay': '2',
#                 'estimatedRunway': '2020-08-12T04:16:00.000',
#                 'estimatedTime': '2020-08-12T04:29:00.000',
#                 'gate': None,
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-12T04:15:00.000',
#                 'terminal': None},
#   'flight': {'iataNumber': 'A81722', 'icaoNumber': 'AMF1722', 'number': '1722'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'FX', 'icaoCode': 'FDX', 'name': 'FedEx'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': None,
#               'gate': None,
#               'iataCode': 'ONT',
#               'icaoCode': 'KONT',
#               'scheduledTime': '2020-08-12T06:09:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': None,
#                 'actualTime': None,
#                 'baggage': None,
#                 'delay': '86',
#                 'estimatedRunway': None,
#                 'estimatedTime': '2020-08-12T06:16:00.000',
#                 'gate': None,
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-12T04:50:00.000',
#                 'terminal': None},
#   'flight': {'iataNumber': 'FX1471', 'icaoNumber': 'FDX1471', 'number': '1471'},
#   'status': 'scheduled',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'AS', 'icaoCode': 'ASA', 'name': 'Alaska Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': '24',
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-12T09:00:00.000',
#               'gate': 'D23',
#               'iataCode': 'MIA',
#               'icaoCode': 'KMIA',
#               'scheduledTime': '2020-08-12T09:21:00.000',
#               'terminal': 'N'},
#   'codeshared': {'airline': {'iataCode': 'aa',
#                              'icaoCode': 'aal',
#                              'name': 'american airlines'},
#                  'flight': {'iataNumber': 'aa2567',
#                             'icaoNumber': 'aal2567',
#                             'number': '2567'}},
#   'departure': {'actualRunway': '2020-08-12T05:36:00.000',
#                 'actualTime': '2020-08-12T05:36:00.000',
#                 'baggage': None,
#                 'delay': '6',
#                 'estimatedRunway': '2020-08-12T05:36:00.000',
#                 'estimatedTime': '2020-08-12T05:33:00.000',
#                 'gate': 'C14',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-12T05:30:00.000',
#                 'terminal': 'C'},
#   'flight': {'iataNumber': 'AS4521', 'icaoNumber': 'ASA4521', 'number': '4521'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'AA', 'icaoCode': 'AAL', 'name': 'American Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': '24',
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-12T09:00:00.000',
#               'gate': 'D23',
#               'iataCode': 'MIA',
#               'icaoCode': 'KMIA',
#               'scheduledTime': '2020-08-12T09:21:00.000',
#               'terminal': 'N'},
#   'codeshared': None,
#   'departure': {'actualRunway': '2020-08-12T05:36:00.000',
#                 'actualTime': '2020-08-12T05:36:00.000',
#                 'baggage': None,
#                 'delay': '6',
#                 'estimatedRunway': '2020-08-12T05:36:00.000',
#                 'estimatedTime': '2020-08-12T05:33:00.000',
#                 'gate': 'C14',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-12T05:30:00.000',
#                 'terminal': 'C'},
#   'flight': {'iataNumber': 'AA2567', 'icaoNumber': 'AAL2567', 'number': '2567'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'MRA', 'icaoCode': 'MRA', 'name': 'Martinaire'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': None,
#               'gate': None,
#               'iataCode': 'PSN',
#               'icaoCode': 'KPSN',
#               'scheduledTime': '2020-08-12T06:34:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': None,
#                 'actualTime': None,
#                 'baggage': None,
#                 'delay': '42',
#                 'estimatedRunway': None,
#                 'estimatedTime': '2020-08-12T06:12:00.000',
#                 'gate': None,
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-12T05:30:00.000',
#                 'terminal': None},
#   'flight': {'iataNumber': 'MRA658', 'icaoNumber': 'MRA658', 'number': '658'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'NK', 'icaoCode': 'NKS', 'name': 'Spirit Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-12T09:05:00.000',
#               'gate': 'G6',
#               'iataCode': 'FLL',
#               'icaoCode': 'KFLL',
#               'scheduledTime': '2020-08-12T09:29:00.000',
#               'terminal': '4'},
#   'codeshared': None,
#   'departure': {'actualRunway': '2020-08-12T05:41:00.000',
#                 'actualTime': '2020-08-12T05:41:00.000',
#                 'baggage': None,
#                 'delay': '7',
#                 'estimatedRunway': '2020-08-12T05:41:00.000',
#                 'estimatedTime': '2020-08-12T05:46:00.000',
#                 'gate': 'E33',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-12T05:35:00.000',
#                 'terminal': 'E'},
#   'flight': {'iataNumber': 'NK1972', 'icaoNumber': 'NKS1972', 'number': '1972'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'CA', 'icaoCode': 'CCA', 'name': 'Air China LTD'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': None,
#               'gate': None,
#               'iataCode': 'JFK',
#               'icaoCode': 'KJFK',
#               'scheduledTime': '2020-08-12T10:00:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': None,
#                 'actualTime': None,
#                 'baggage': None,
#                 'delay': None,
#                 'estimatedRunway': None,
#                 'estimatedTime': None,
#                 'gate': None,
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-12T05:40:00.000',
#                 'terminal': None},
#   'flight': {'iataNumber': 'CA1050', 'icaoNumber': 'CCA1050', 'number': '1050'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'AA', 'icaoCode': 'AAL', 'name': 'American Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': 'D',
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-12T09:58:00.000',
#               'gate': 'B5',
#               'iataCode': 'PHL',
#               'icaoCode': 'KPHL',
#               'scheduledTime': '2020-08-12T10:15:00.000',
#               'terminal': 'B'},
#   'codeshared': None,
#   'departure': {'actualRunway': '2020-08-12T06:05:00.000',
#                 'actualTime': '2020-08-12T06:05:00.000',
#                 'baggage': None,
#                 'delay': '6',
#                 'estimatedRunway': '2020-08-12T06:05:00.000',
#                 'estimatedTime': '2020-08-12T06:12:00.000',
#                 'gate': 'D31',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-12T06:00:00.000',
#                 'terminal': 'D'},
#   'flight': {'iataNumber': 'AA856', 'icaoNumber': 'AAL856', 'number': '856'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'AM', 'icaoCode': 'AMX', 'name': 'Aeromexico'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': '6',
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-12T08:52:00.000',
#               'gate': 'B04',
#               'iataCode': 'ATL',
#               'icaoCode': 'KATL',
#               'scheduledTime': '2020-08-12T09:05:00.000',
#               'terminal': 'S'},
#   'codeshared': {'airline': {'iataCode': 'dl',
#                              'icaoCode': 'dal',
#                              'name': 'delta air lines'},
#                  'flight': {'iataNumber': 'dl1188',
#                             'icaoNumber': 'dal1188',
#                             'number': '1188'}},
#   'departure': {'actualRunway': '2020-08-12T06:10:00.000',
#                 'actualTime': '2020-08-12T06:10:00.000',
#                 'baggage': None,
#                 'delay': '10',
#                 'estimatedRunway': '2020-08-12T06:10:00.000',
#                 'estimatedTime': '2020-08-12T06:17:00.000',
#                 'gate': 'E14',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-12T06:00:00.000',
#                 'terminal': 'E'},
#   'flight': {'iataNumber': 'AM5132', 'icaoNumber': 'AMX5132', 'number': '5132'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'KE', 'icaoCode': 'KAL', 'name': 'Korean Air'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': '6',
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-12T08:52:00.000',
#               'gate': 'B04',
#               'iataCode': 'ATL',
#               'icaoCode': 'KATL',
#               'scheduledTime': '2020-08-12T09:05:00.000',
#               'terminal': 'S'},
#   'codeshared': {'airline': {'iataCode': 'dl',
#                              'icaoCode': 'dal',
#                              'name': 'delta air lines'},
#                  'flight': {'iataNumber': 'dl1188',
#                             'icaoNumber': 'dal1188',
#                             'number': '1188'}},
#   'departure': {'actualRunway': '2020-08-12T06:10:00.000',
#                 'actualTime': '2020-08-12T06:10:00.000',
#                 'baggage': None,
#                 'delay': '10',
#                 'estimatedRunway': '2020-08-12T06:10:00.000',
#                 'estimatedTime': '2020-08-12T06:17:00.000',
#                 'gate': 'E14',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-12T06:00:00.000',
#                 'terminal': 'E'},
#   'flight': {'iataNumber': 'KE3709', 'icaoNumber': 'KAL3709', 'number': '3709'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'DL', 'icaoCode': 'DAL', 'name': 'Delta Air Lines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': '6',
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-12T08:52:00.000',
#               'gate': 'B04',
#               'iataCode': 'ATL',
#               'icaoCode': 'KATL',
#               'scheduledTime': '2020-08-12T09:05:00.000',
#               'terminal': 'S'},
#   'codeshared': None,
#   'departure': {'actualRunway': '2020-08-12T06:10:00.000',
#                 'actualTime': '2020-08-12T06:10:00.000',
#                 'baggage': None,
#                 'delay': '10',
#                 'estimatedRunway': '2020-08-12T06:10:00.000',
#                 'estimatedTime': '2020-08-12T06:17:00.000',
#                 'gate': 'E14',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-12T06:00:00.000',
#                 'terminal': 'E'},
#   'flight': {'iataNumber': 'DL1188', 'icaoNumber': 'DAL1188', 'number': '1188'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'KE', 'icaoCode': 'KAL', 'name': 'Korean Air'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': '15',
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-12T07:56:00.000',
#               'gate': 'C20',
#               'iataCode': 'SEA',
#               'icaoCode': 'KSEA',
#               'scheduledTime': '2020-08-12T08:14:00.000',
#               'terminal': None},
#   'codeshared': {'airline': {'iataCode': 'as',
#                              'icaoCode': 'asa',
#                              'name': 'alaska airlines'},
#                  'flight': {'iataNumber': 'as756',
#                             'icaoNumber': 'asa756',
#                             'number': '756'}},
#   'departure': {'actualRunway': '2020-08-12T06:14:00.000',
#                 'actualTime': '2020-08-12T06:14:00.000',
#                 'baggage': None,
#                 'delay': '15',
#                 'estimatedRunway': '2020-08-12T06:14:00.000',
#                 'estimatedTime': '2020-08-12T06:12:00.000',
#                 'gate': 'E11',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-12T06:00:00.000',
#                 'terminal': 'E'},
#   'flight': {'iataNumber': 'KE6120', 'icaoNumber': 'KAL6120', 'number': '6120'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'AS', 'icaoCode': 'ASA', 'name': 'Alaska Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': '15',
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-12T07:56:00.000',
#               'gate': 'C20',
#               'iataCode': 'SEA',
#               'icaoCode': 'KSEA',
#               'scheduledTime': '2020-08-12T08:14:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': '2020-08-12T06:14:00.000',
#                 'actualTime': '2020-08-12T06:14:00.000',
#                 'baggage': None,
#                 'delay': '15',
#                 'estimatedRunway': '2020-08-12T06:14:00.000',
#                 'estimatedTime': '2020-08-12T06:12:00.000',
#                 'gate': 'E11',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-12T06:00:00.000',
#                 'terminal': 'E'},
#   'flight': {'iataNumber': 'AS756', 'icaoNumber': 'ASA756', 'number': '756'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'KE', 'icaoCode': 'KAL', 'name': 'Korean Air'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': '8',
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-12T09:26:00.000',
#               'gate': 'A21',
#               'iataCode': 'DTW',
#               'icaoCode': 'KDTW',
#               'scheduledTime': '2020-08-12T09:35:00.000',
#               'terminal': 'EM'},
#   'codeshared': {'airline': {'iataCode': 'dl',
#                              'icaoCode': 'dal',
#                              'name': 'delta air lines'},
#                  'flight': {'iataNumber': 'dl779',
#                             'icaoNumber': 'dal779',
#                             'number': '779'}},
#   'departure': {'actualRunway': '2020-08-12T06:13:00.000',
#                 'actualTime': '2020-08-12T06:13:00.000',
#                 'baggage': None,
#                 'delay': '13',
#                 'estimatedRunway': '2020-08-12T06:13:00.000',
#                 'estimatedTime': '2020-08-12T06:09:00.000',
#                 'gate': 'E17',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-12T06:00:00.000',
#                 'terminal': 'E'},
#   'flight': {'iataNumber': 'KE3408', 'icaoNumber': 'KAL3408', 'number': '3408'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'DL', 'icaoCode': 'DAL', 'name': 'Delta Air Lines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': '8',
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-12T09:26:00.000',
#               'gate': 'A21',
#               'iataCode': 'DTW',
#               'icaoCode': 'KDTW',
#               'scheduledTime': '2020-08-12T09:35:00.000',
#               'terminal': 'EM'},
#   'codeshared': None,
#   'departure': {'actualRunway': '2020-08-12T06:13:00.000',
#                 'actualTime': '2020-08-12T06:13:00.000',
#                 'baggage': None,
#                 'delay': '13',
#                 'estimatedRunway': '2020-08-12T06:13:00.000',
#                 'estimatedTime': '2020-08-12T06:09:00.000',
#                 'gate': 'E17',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-12T06:00:00.000',
#                 'terminal': 'E'},
#   'flight': {'iataNumber': 'DL779', 'icaoNumber': 'DAL779', 'number': '779'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'AM', 'icaoCode': 'AMX', 'name': 'Aeromexico'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-12T07:26:00.000',
#               'gate': 'C6',
#               'iataCode': 'SLC',
#               'icaoCode': 'KSLC',
#               'scheduledTime': '2020-08-12T07:41:00.000',
#               'terminal': '2'},
#   'codeshared': {'airline': {'iataCode': 'dl',
#                              'icaoCode': 'dal',
#                              'name': 'delta air lines'},
#                  'flight': {'iataNumber': 'dl1738',
#                             'icaoNumber': 'dal1738',
#                             'number': '1738'}},
#   'departure': {'actualRunway': '2020-08-12T06:07:00.000',
#                 'actualTime': '2020-08-12T06:07:00.000',
#                 'baggage': None,
#                 'delay': '8',
#                 'estimatedRunway': '2020-08-12T06:07:00.000',
#                 'estimatedTime': '2020-08-12T06:01:00.000',
#                 'gate': 'E15',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-12T06:00:00.000',
#                 'terminal': 'E'},
#   'flight': {'iataNumber': 'AM3194', 'icaoNumber': 'AMX3194', 'number': '3194'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'WS', 'icaoCode': 'WJA', 'name': 'WestJet'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-12T07:26:00.000',
#               'gate': 'C6',
#               'iataCode': 'SLC',
#               'icaoCode': 'KSLC',
#               'scheduledTime': '2020-08-12T07:41:00.000',
#               'terminal': '2'},
#   'codeshared': {'airline': {'iataCode': 'dl',
#                              'icaoCode': 'dal',
#                              'name': 'delta air lines'},
#                  'flight': {'iataNumber': 'dl1738',
#                             'icaoNumber': 'dal1738',
#                             'number': '1738'}},
#   'departure': {'actualRunway': '2020-08-12T06:07:00.000',
#                 'actualTime': '2020-08-12T06:07:00.000',
#                 'baggage': None,
#                 'delay': '8',
#                 'estimatedRunway': '2020-08-12T06:07:00.000',
#                 'estimatedTime': '2020-08-12T06:01:00.000',
#                 'gate': 'E15',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-12T06:00:00.000',
#                 'terminal': 'E'},
#   'flight': {'iataNumber': 'WS6389', 'icaoNumber': 'WJA6389', 'number': '6389'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'DL', 'icaoCode': 'DAL', 'name': 'Delta Air Lines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-12T07:26:00.000',
#               'gate': 'C6',
#               'iataCode': 'SLC',
#               'icaoCode': 'KSLC',
#               'scheduledTime': '2020-08-12T07:41:00.000',
#               'terminal': '2'},
#   'codeshared': None,
#   'departure': {'actualRunway': '2020-08-12T06:07:00.000',
#                 'actualTime': '2020-08-12T06:07:00.000',
#                 'baggage': None,
#                 'delay': '8',
#                 'estimatedRunway': '2020-08-12T06:07:00.000',
#                 'estimatedTime': '2020-08-12T06:01:00.000',
#                 'gate': 'E15',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-12T06:00:00.000',
#                 'terminal': 'E'},
#   'flight': {'iataNumber': 'DL1738', 'icaoNumber': 'DAL1738', 'number': '1738'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'Y4', 'icaoCode': 'VOI', 'name': 'Volaris'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': '4',
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-12T06:56:00.000',
#               'gate': 'A52',
#               'iataCode': 'DEN',
#               'icaoCode': 'KDEN',
#               'scheduledTime': '2020-08-12T07:18:00.000',
#               'terminal': None},
#   'codeshared': {'airline': {'iataCode': 'f9',
#                              'icaoCode': 'fft',
#                              'name': 'frontier airlines'},
#                  'flight': {'iataNumber': 'f9263',
#                             'icaoNumber': 'fft263',
#                             'number': '263'}},
#   'departure': {'actualRunway': '2020-08-12T06:22:00.000',
#                 'actualTime': '2020-08-12T06:22:00.000',
#                 'baggage': None,
#                 'delay': '13',
#                 'estimatedRunway': '2020-08-12T06:22:00.000',
#                 'estimatedTime': '2020-08-12T06:24:00.000',
#                 'gate': 'E20',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-12T06:09:00.000',
#                 'terminal': 'E'},
#   'flight': {'iataNumber': 'Y42213', 'icaoNumber': 'VOI2213', 'number': '2213'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'F9', 'icaoCode': 'FFT', 'name': 'Frontier Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': '4',
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-12T06:56:00.000',
#               'gate': 'A52',
#               'iataCode': 'DEN',
#               'icaoCode': 'KDEN',
#               'scheduledTime': '2020-08-12T07:18:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': '2020-08-12T06:22:00.000',
#                 'actualTime': '2020-08-12T06:22:00.000',
#                 'baggage': None,
#                 'delay': '13',
#                 'estimatedRunway': '2020-08-12T06:22:00.000',
#                 'estimatedTime': '2020-08-12T06:24:00.000',
#                 'gate': 'E20',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-12T06:09:00.000',
#                 'terminal': 'E'},
#   'flight': {'iataNumber': 'F9263', 'icaoNumber': 'FFT263', 'number': '263'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'WS', 'icaoCode': 'WJA', 'name': 'WestJet'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': 'D1',
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-12T10:19:00.000',
#               'gate': 'D11',
#               'iataCode': 'LGA',
#               'icaoCode': 'KLGA',
#               'scheduledTime': '2020-08-12T10:38:00.000',
#               'terminal': 'D'},
#   'codeshared': {'airline': {'iataCode': 'dl',
#                              'icaoCode': 'dal',
#                              'name': 'delta air lines'},
#                  'flight': {'iataNumber': 'dl832',
#                             'icaoNumber': 'dal832',
#                             'number': '832'}},
#   'departure': {'actualRunway': '2020-08-12T06:21:00.000',
#                 'actualTime': '2020-08-12T06:21:00.000',
#                 'baggage': None,
#                 'delay': '6',
#                 'estimatedRunway': '2020-08-12T06:21:00.000',
#                 'estimatedTime': '2020-08-12T06:19:00.000',
#                 'gate': 'E13',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-12T06:15:00.000',
#                 'terminal': 'E'},
#   'flight': {'iataNumber': 'WS6638', 'icaoNumber': 'WJA6638', 'number': '6638'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'DL', 'icaoCode': 'DAL', 'name': 'Delta Air Lines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': 'D1',
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-12T10:19:00.000',
#               'gate': 'D11',
#               'iataCode': 'LGA',
#               'icaoCode': 'KLGA',
#               'scheduledTime': '2020-08-12T10:38:00.000',
#               'terminal': 'D'},
#   'codeshared': None,
#   'departure': {'actualRunway': '2020-08-12T06:21:00.000',
#                 'actualTime': '2020-08-12T06:21:00.000',
#                 'baggage': None,
#                 'delay': '6',
#                 'estimatedRunway': '2020-08-12T06:21:00.000',
#                 'estimatedTime': '2020-08-12T06:19:00.000',
#                 'gate': 'E13',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-12T06:15:00.000',
#                 'terminal': 'E'},
#   'flight': {'iataNumber': 'DL832', 'icaoNumber': 'DAL832', 'number': '832'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'MRA', 'icaoCode': 'MRA', 'name': 'Martinaire'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': None,
#               'gate': None,
#               'iataCode': 'ABI',
#               'icaoCode': 'KABI',
#               'scheduledTime': '2020-08-12T07:56:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': '2020-08-12T06:59:00.000',
#                 'actualTime': '2020-08-12T06:59:00.000',
#                 'baggage': None,
#                 'delay': '45',
#                 'estimatedRunway': '2020-08-12T06:59:00.000',
#                 'estimatedTime': '2020-08-12T06:26:00.000',
#                 'gate': None,
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-12T06:15:00.000',
#                 'terminal': None},
#   'flight': {'iataNumber': 'MRA662', 'icaoNumber': 'MRA662', 'number': '662'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'NK', 'icaoCode': 'NKS', 'name': 'Spirit Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-12T07:09:00.000',
#               'gate': None,
#               'iataCode': 'LAX',
#               'icaoCode': 'KLAX',
#               'scheduledTime': '2020-08-12T07:36:00.000',
#               'terminal': '5'},
#   'codeshared': None,
#   'departure': {'actualRunway': '2020-08-12T06:29:00.000',
#                 'actualTime': '2020-08-12T06:29:00.000',
#                 'baggage': None,
#                 'delay': '9',
#                 'estimatedRunway': '2020-08-12T06:29:00.000',
#                 'estimatedTime': '2020-08-12T06:28:00.000',
#                 'gate': 'E31',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-12T06:20:00.000',
#                 'terminal': 'E'},
#   'flight': {'iataNumber': 'NK867', 'icaoNumber': 'NKS867', 'number': '867'},
#   'status': 'active',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'MRA', 'icaoCode': 'MRA', 'name': 'Martinaire'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': '2020-08-12T07:50:00.000',
#               'gate': None,
#               'iataCode': 'ABI',
#               'icaoCode': 'KABI',
#               'scheduledTime': '2020-08-12T07:50:00.000',
# ...
#                 'terminal': None},
#   'flight': {'iataNumber': '5X2954', 'icaoNumber': 'UPS2954', 'number': '2954'},
#   'status': 'scheduled',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'AA', 'icaoCode': 'AAL', 'name': 'American Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': 'C1',
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': None,
#               'gate': '84',
#               'iataCode': 'MCI',
#               'icaoCode': 'KMCI',
#               'scheduledTime': '2020-08-12T17:03:00.000',
#               'terminal': 'C'},
#   'codeshared': None,
#   'departure': {'actualRunway': None,
#                 'actualTime': None,
#                 'baggage': None,
#                 'delay': '12',
#                 'estimatedRunway': None,
#                 'estimatedTime': '2020-08-12T15:40:00.000',
#                 'gate': 'C27',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-12T15:28:00.000',
#                 'terminal': 'C'},
#   'flight': {'iataNumber': 'AA2055', 'icaoNumber': 'AAL2055', 'number': '2055'},
#   'status': 'scheduled',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'AA', 'icaoCode': 'AAL', 'name': 'American Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': '2',
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': None,
#               'gate': 'D8',
#               'iataCode': 'LGA',
#               'icaoCode': 'KLGA',
#               'scheduledTime': '2020-08-12T19:59:00.000',
#               'terminal': 'B'},
#   'codeshared': None,
#   'departure': {'actualRunway': None,
#                 'actualTime': None,
#                 'baggage': None,
#                 'delay': '12',
#                 'estimatedRunway': None,
#                 'estimatedTime': '2020-08-12T15:40:00.000',
#                 'gate': 'C16',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-12T15:28:00.000',
#                 'terminal': 'C'},
#   'flight': {'iataNumber': 'AA2716', 'icaoNumber': 'AAL2716', 'number': '2716'},
#   'status': 'scheduled',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'AA', 'icaoCode': 'AAL', 'name': 'American Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': '3',
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': None,
#               'gate': '30',
#               'iataCode': 'AUS',
#               'icaoCode': 'KAUS',
#               'scheduledTime': '2020-08-12T16:27:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': None,
#                 'actualTime': None,
#                 'baggage': None,
#                 'delay': '12',
#                 'estimatedRunway': None,
#                 'estimatedTime': '2020-08-12T15:42:00.000',
#                 'gate': 'A37',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-12T15:30:00.000',
#                 'terminal': 'A'},
#   'flight': {'iataNumber': 'AA1004', 'icaoNumber': 'AAL1004', 'number': '1004'},
#   'status': 'scheduled',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'AA', 'icaoCode': 'AAL', 'name': 'American Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': None,
#               'gate': 'A18',
#               'iataCode': 'PHX',
#               'icaoCode': 'KPHX',
#               'scheduledTime': '2020-08-12T15:55:00.000',
#               'terminal': '4'},
#   'codeshared': None,
#   'departure': {'actualRunway': None,
#                 'actualTime': None,
#                 'baggage': None,
#                 'delay': '12',
#                 'estimatedRunway': None,
#                 'estimatedTime': '2020-08-12T15:42:00.000',
#                 'gate': 'B6',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-12T15:30:00.000',
#                 'terminal': 'B'},
#   'flight': {'iataNumber': 'AA1885', 'icaoNumber': 'AAL1885', 'number': '1885'},
#   'status': 'scheduled',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'AA', 'icaoCode': 'AAL', 'name': 'American Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': None,
#               'gate': '3',
#               'iataCode': 'GJT',
#               'icaoCode': 'KGJT',
#               'scheduledTime': '2020-08-12T16:38:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': None,
#                 'actualTime': None,
#                 'baggage': None,
#                 'delay': '15',
#                 'estimatedRunway': None,
#                 'estimatedTime': '2020-08-12T15:45:00.000',
#                 'gate': 'B18',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-12T15:30:00.000',
#                 'terminal': 'B'},
#   'flight': {'iataNumber': 'AA4162', 'icaoNumber': 'AAL4162', 'number': '4162'},
#   'status': 'scheduled',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'AA', 'icaoCode': 'AAL', 'name': 'American Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': None,
#               'gate': '1',
#               'iataCode': 'ACT',
#               'icaoCode': 'KACT',
#               'scheduledTime': '2020-08-12T16:20:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': None,
#                 'actualTime': None,
#                 'baggage': None,
#                 'delay': '15',
#                 'estimatedRunway': None,
#                 'estimatedTime': '2020-08-12T15:55:00.000',
#                 'gate': 'E28',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-12T15:40:00.000',
#                 'terminal': 'E'},
#   'flight': {'iataNumber': 'AA3810', 'icaoNumber': 'AAL3810', 'number': '3810'},
#   'status': 'scheduled',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'NK', 'icaoCode': 'NKS', 'name': 'Spirit Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': None,
#               'gate': 'D16',
#               'iataCode': 'DTW',
#               'icaoCode': 'KDTW',
#               'scheduledTime': '2020-08-12T19:17:00.000',
#               'terminal': 'N'},
#   'codeshared': None,
#   'departure': {'actualRunway': None,
#                 'actualTime': None,
#                 'baggage': None,
#                 'delay': '11',
#                 'estimatedRunway': None,
#                 'estimatedTime': '2020-08-12T15:51:00.000',
#                 'gate': 'E33',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-12T15:40:00.000',
#                 'terminal': 'E'},
#   'flight': {'iataNumber': 'NK734', 'icaoNumber': 'NKS734', 'number': '734'},
#   'status': 'scheduled',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'AA', 'icaoCode': 'AAL', 'name': 'American Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': '5',
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': None,
#               'gate': 'D32',
#               'iataCode': 'DTW',
#               'icaoCode': 'KDTW',
#               'scheduledTime': '2020-08-12T19:21:00.000',
#               'terminal': 'N'},
#   'codeshared': None,
#   'departure': {'actualRunway': None,
#                 'actualTime': None,
#                 'baggage': None,
#                 'delay': '12',
#                 'estimatedRunway': None,
#                 'estimatedTime': '2020-08-12T15:52:00.000',
#                 'gate': 'D40',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-12T15:40:00.000',
#                 'terminal': 'D'},
#   'flight': {'iataNumber': 'AA315', 'icaoNumber': 'AAL315', 'number': '315'},
#   'status': 'scheduled',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'DL', 'icaoCode': 'DAL', 'name': 'Delta Air Lines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': '2',
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': None,
#               'gate': '27',
#               'iataCode': 'LAX',
#               'icaoCode': 'KLAX',
#               'scheduledTime': '2020-08-12T16:55:00.000',
#               'terminal': '2'},
#   'codeshared': None,
#   'departure': {'actualRunway': None,
#                 'actualTime': None,
#                 'baggage': None,
#                 'delay': '10',
#                 'estimatedRunway': None,
#                 'estimatedTime': '2020-08-12T15:59:00.000',
#                 'gate': 'E13',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-12T15:49:00.000',
#                 'terminal': 'E'},
#   'flight': {'iataNumber': 'DL1357', 'icaoNumber': 'DAL1357', 'number': '1357'},
#   'status': 'scheduled',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'AA', 'icaoCode': 'AAL', 'name': 'American Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': None,
#               'gate': 'B16',
#               'iataCode': 'MSY',
#               'icaoCode': 'KMSY',
#               'scheduledTime': '2020-08-12T17:17:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': None,
#                 'actualTime': None,
#                 'baggage': None,
#                 'delay': '12',
#                 'estimatedRunway': None,
#                 'estimatedTime': '2020-08-12T16:03:00.000',
#                 'gate': 'C31',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-12T15:51:00.000',
#                 'terminal': 'C'},
#   'flight': {'iataNumber': 'AA2184', 'icaoNumber': 'AAL2184', 'number': '2184'},
#   'status': 'scheduled',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'AA', 'icaoCode': 'AAL', 'name': 'American Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': None,
#               'gate': 'G07',
#               'iataCode': 'AMS',
#               'icaoCode': 'EHAM',
#               'scheduledTime': '2020-08-13T08:15:00.000',
#               'terminal': '3'},
#   'codeshared': None,
#   'departure': {'actualRunway': None,
#                 'actualTime': None,
#                 'baggage': None,
#                 'delay': '12',
#                 'estimatedRunway': None,
#                 'estimatedTime': '2020-08-12T16:12:00.000',
#                 'gate': 'A24',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-12T16:00:00.000',
#                 'terminal': 'A'},
#   'flight': {'iataNumber': 'AA220', 'icaoNumber': 'AAL220', 'number': '220'},
#   'status': 'scheduled',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'AS', 'icaoCode': 'ASA', 'name': 'Alaska Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': '3',
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': None,
#               'gate': 'C8',
#               'iataCode': 'PDX',
#               'icaoCode': 'KPDX',
#               'scheduledTime': '2020-08-12T17:45:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': None,
#                 'actualTime': None,
#                 'baggage': None,
#                 'delay': '13',
#                 'estimatedRunway': None,
#                 'estimatedTime': '2020-08-12T16:13:00.000',
#                 'gate': 'E11',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-12T16:00:00.000',
#                 'terminal': 'E'},
#   'flight': {'iataNumber': 'AS655', 'icaoNumber': 'ASA655', 'number': '655'},
#   'status': 'scheduled',
#   'type': 'departure'},
#  {'airline': {'iataCode': 'DL', 'icaoCode': 'DAL', 'name': 'Delta Air Lines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': '8',
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': None,
#               'gate': 'A23',
#               'iataCode': 'DTW',
#               'icaoCode': 'KDTW',
#               'scheduledTime': '2020-08-12T19:36:00.000',
#               'terminal': 'EM'},
#   'codeshared': None,
#   'departure': {'actualRunway': None,
#                 'actualTime': None,
#                 'baggage': None,
#                 'delay': '4',
#                 'estimatedRunway': None,
#                 'estimatedTime': '2020-08-12T16:04:00.000',
#                 'gate': 'E14',
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-12T16:00:00.000',
#                 'terminal': 'E'},
#   'flight': {'iataNumber': 'DL1505', 'icaoNumber': 'DAL1505', 'number': '1505'},
#   'status': 'scheduled',
#   'type': 'departure'},
#  {'airline': {'iataCode': '5X', 'icaoCode': 'UPS', 'name': 'UPS Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': None,
#               'gate': None,
#               'iataCode': 'ABQ',
#               'icaoCode': 'KABQ',
#               'scheduledTime': '2020-08-12T16:36:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': None,
#                 'actualTime': None,
#                 'baggage': None,
#                 'delay': None,
#                 'estimatedRunway': None,
#                 'estimatedTime': None,
#                 'gate': None,
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-12T16:00:00.000',
#                 'terminal': None},
#   'flight': {'iataNumber': '5X2906', 'icaoNumber': 'UPS2906', 'number': '2906'},
#   'status': 'scheduled',
#   'type': 'departure'},
#  {'airline': {'iataCode': '5X', 'icaoCode': 'UPS', 'name': 'UPS Airlines'},
#   'arrival': {'actualRunway': None,
#               'actualTime': None,
#               'baggage': None,
#               'delay': None,
#               'estimatedRunway': None,
#               'estimatedTime': None,
#               'gate': None,
#               'iataCode': 'ONT',
#               'icaoCode': 'KONT',
#               'scheduledTime': '2020-08-12T16:42:00.000',
#               'terminal': None},
#   'codeshared': None,
#   'departure': {'actualRunway': None,
#                 'actualTime': None,
#                 'baggage': None,
#                 'delay': None,
#                 'estimatedRunway': None,
#                 'estimatedTime': None,
#                 'gate': None,
#                 'iataCode': 'DFW',
#                 'icaoCode': 'KDFW',
#                 'scheduledTime': '2020-08-12T16:00:00.000',
#                 'terminal': None},
#   'flight': {'iataNumber': '5X2918', 'icaoNumber': 'UPS2918', 'number': '2918'},
#   'status': 'scheduled',
#   'type': 'departure'}]

# %%
#JB-added terminal to the list which will give us another lookup option
names= []
times= []
flights=[]
terminal= []
length = int(len(data)-1)

for x in range(0,length):
    names.append(data[x]["airline"]["name"])
    Time = data[x]["departure"]["scheduledTime"]
    TimeSplit = Time.split("T")[1]
    times.append(TimeSplit[:5])
    flights.append(data[x]["flight"]["iataNumber"])
    terminal.append(data[x]["departure"]["terminal"])
df = pd.DataFrame()
df["name"] =names
df["scheduledTime"] =pd.to_datetime(times)
df["iataNumber"]=flights
df["Terminal"]=terminal

#df.to_csv("airport_data.csv", encoding="utf-8", index=False, header=True)
test = df.groupby(["scheduledTime"])["iataNumber"].count()
test.plot(kind="line", title="Flight per Hour", figsize = (20,10))
plt.xlim("2020-08-12 06:00:00","2020-08-12 21:00:00")
#xticks=["midnight","3am","6am","9am","noon","3pm","6pm","9pm","midnight"]
# Out:
# (737649.25, 737649.875)
